# %%
# !pip install transformers datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.29.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
# !pip install progress
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: progress in /usr/local/lib/python3.10/dist-packages (1.6)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, T5ForConditionalGeneration, T5Config, AdamW
from datasets import load_dataset
from datasets import Dataset, DatasetDict
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import pandas as pd
#!pip install SentencePiece

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# https://github.com/shahparth123/eng_guj_parallel_corpus

# %%
# Load the dataset for Fr to English translation
# Read the text file and split lines
with open('Data/gujarati.txt', "r") as text_file:
    guj_lines = text_file.read().splitlines()

# Create DataFrame from lines
guj_data= pd.DataFrame(guj_lines, columns=["text"])


with open('Data/english.txt', "r") as text_file:
    eng_lines = text_file.read().splitlines()

# Create DataFrame from lines
eng_data = pd.DataFrame(eng_lines, columns=["text"])

# %%
eng_data.head()
# Out:
#                                                 text
# 0  A bicycle replica with a clock as the front wh...
# 1  A black Honda motorcycle parked in front of a ...
# 2  A room with blue walls and a white sink and door.
# 3  A car that seems to be parked illegally behind...
# 4  A large passenger airplane flying through the ...

# %%
guj_data.head()
# Out:
#                                                 text
# 0    ફ્રન્ટ વ્હીલ તરીકે ઘડિયાળ સાથે સાયકલ પ્રતિકૃતિ.
# 1    ગેરેજની સામે પાર્ક કરેલી બ્લેક હોન્ડા મોટરસાયકલ
# 2   વાદળી દિવાલો અને સફેદ સિંક અને બારણું ધરાવતી ખંડ
# 3  એક કાર કે જે કાનૂની રીતે પાર્ક કરેલી કારની પાછ...
# 4                   હવામાં ઉડતી મોટી પેસેન્જર વિમાન.

# %% [markdown]
# ## Merge Columns in one DF

# %%
 # Merge the DataFrames based on their columns
data = pd.merge(eng_data, guj_data, left_index=True, right_index=True)
data.columns = ['en','gu']
data.head()
# Out:
#                                                   en  \
# 0  A bicycle replica with a clock as the front wh...
# 1  A black Honda motorcycle parked in front of a ...
# 2  A room with blue walls and a white sink and door.
# 3  A car that seems to be parked illegally behind...
# 4  A large passenger airplane flying through the ...
#
#                                                   gu
# 0    ફ્રન્ટ વ્હીલ તરીકે ઘડિયાળ સાથે સાયકલ પ્રતિકૃતિ.
# 1    ગેરેજની સામે પાર્ક કરેલી બ્લેક હોન્ડા મોટરસાયકલ
# 2   વાદળી દિવાલો અને સફેદ સિંક અને બારણું ધરાવતી ખંડ
# 3  એક કાર કે જે કાનૂની રીતે પાર્ક કરેલી કારની પાછ...
# 4                   હવામાં ઉડતી મોટી પેસેન્જર વિમાન.

# %%
# Split the data into train and test sets
train_df, test_df = train_test_split(data, test_size=0.2, random_state=42)

# Split the train set further into train and validation sets
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)

# %%
# Assuming you have a DataFrame named 'df'
def fun_to_dic(df):
  var_dic = {}
  lst = []
  for index, row in df.iterrows():
      # 'row' is a Series object representing a single row
      new_dict={'en':row['en'],'gu':row['gu']}
      lst.append(new_dict)
  var_dic['translation'] = lst
  return var_dic

# %%
# Create a Dataset object for each split
train_dataset = Dataset.from_dict(fun_to_dic(train_df))
val_dataset = Dataset.from_dict(fun_to_dic(val_df))
test_dataset = Dataset.from_dict(fun_to_dic(test_df))

# %%
# Create a DatasetDict object with the splits
dataset = DatasetDict({
    'train': train_dataset,
    'validation': val_dataset,
    'test': test_dataset
})

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 41600
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 10400
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 13000
#     })
# })

# %%
# Extract the appropriate keys for source and target translations
source_key = "translation" if "translation" in dataset["train"][0].keys() else "translations"
target_key = "translation" if "translation" in dataset["train"][0].keys() else "translations"
target_key
# Out:
# 'translation'

# %%
dataset["train"]['translation']
# Out:
# [{'en': 'Small jet sits on tarmac of airport on sunny day.',
#   'gu': 'નાના જેટ સન્ની દિવસે એરપોર્ટની ડામર પર આવેલું છે.'},
#  {'en': 'A cow standing next to a white wall and bright blue door.',
#   'gu': 'એક સફેદ દિવાલ અને તેજસ્વી વાદળી બારણું આગળ એક ગાય ઊભા.'},
#  {'en': 'A motorcycle and car parked on the street.',
#   'gu': 'એક મોટરસાઇકલ અને કાર શેરીમાં પાર્ક છે.'},
#  {'en': 'A man and woman are riding a motorcycle and the woman is carrying a DSW bag.',
#   'gu': 'એક માણસ અને સ્ત્રી મોટરસાઇકલ પર સવારી કરે છે અને મહિલા એક ડીએસડબલ્યુ બેગ ધરાવે છે.'},
#  {'en': 'A kitchen filled with wooden cabinets and a table.',
#   'gu': 'લાકડાના કેબિનેટ્સ અને કોષ્ટકથી ભરપૂર રસોડું.'},
#  {'en': 'Two motorcyclists near a purple motorcycle towing a trailer.',
#   'gu': 'એક ટ્રેલર ટાઈપ જાંબલી મોટરસાઇકલ નજીક બે મોટરસાયક્લીસ્ટોના.'},
#  {'en': ' A road with pavement on which street sign board is attached on a pole.A cycle is standing by the pole. ',
#   'gu': '\xa0પેવમેન્ટ સાથેનો રસ્તો, જેના પર ધ્રુવ પર શેરી સાઇન બોર્ડ જોડાય છે. એક ચક્ર ધ્રુવ દ્વારા ઊભો છે.'},
#  {'en': 'A jet soaring into a cloudy gray sky.',
#   'gu': 'એક વાદળ ઘેરા વાદળા આકાશમાં ઊડતા વિમાન.'},
#  {'en': 'a red and white plane is flying over some water ',
#   'gu': 'લાલ અને સફેદ વિમાન કેટલાક પાણી પર ઉડતી હોય છે'},
#  {'en': 'A zebra with its head down and a giraffe in the background eating from a tree',
#   'gu': 'તેના ઝાડ નીચે ઝેબ્રા અને એક ઝાડમાંથી ખાતા પૃષ્ઠભૂમિમાં જિરાફ'},
#  {'en': 'A red all terrain vehicle next to a man with a green dirt bike.',
#   'gu': 'ગ્રીન ડર્ટ બાઇક ધરાવતી એક માણસ પાસે લાલ બધા ભૂપ્રદેશ વાહન.'},
#  {'en': 'A piece of cake with yellow drizzle is sitting on a white plate.',
#   'gu': 'પીળા ઝરમર વરસાદ સાથે કેકનો ટુકડો સફેદ પ્લેટ પર બેઠા છે.'},
#  {'en': 'a bridge lit up with some  blue lights ',
#   'gu': 'એક બ્રિજ કેટલાક વાદળી લાઇટ સાથે પ્રગટાવવામાં'},
#  {'en': 'A man riding a bicycle with a man standing on back of it.',
#   'gu': 'એક માણસ તેની પાછળ ઊભેલા માણસ સાથે સાયકલ ચલાવે છે.'},
#  {'en': 'A city street filled with lots of traffic and pedestrians.',
#   'gu': 'શહેરની શેરીમાં ઘણા ટ્રાફિક અને પદયાત્રીઓ સાથે ભરવામાં આવે છે.'},
#  {'en': 'A gang of bikers driving down a rural country road.',
#   'gu': 'ગ્રામીણ દેશ રસ્તાને નીચે ઉતરતા બાઇકરોનું એક ગેંગ'},
#  {'en': 'Some yellow street lights on some poles in the middle of a street.',
#   'gu': 'શેરીના મધ્યમાં કેટલાક ધ્રુવો પર કેટલાક પીળા શેરી લાઇટ.'},
#  {'en': 'A black and white picture of people in a kitchen. ',
#   'gu': 'રસોડામાં લોકોનો કાળો અને સફેદ ચિત્ર'},
#  {'en': 'A red stop sign that reads " Eating Animals " below it.',
#   'gu': 'એક લાલ સ્ટોપ સાઇન તે નીચે "પ્રાણીઓ વિશેષ" વાંચે છે.'},
#  {'en': 'A bathroom with a toilet mop bucket and squeegee in it. ',
#   'gu': 'શૌચાલય મોપ બકેટ અને બાથરૂમમાં બાથરૂમ.'},
#  {'en': 'A bathroom with a toilet and a drain in it. ',
#   'gu': 'તેમાં શૌચાલય અને ગટરમાં એક બાથરૂમ.'},
#  {'en': 'Black dog sitting on wooden floor watching television in living area.',
#   'gu': 'વસવાટ કરો છો વિસ્તારમાં ટેલિવિઝન જોવા લાકડાના ફ્લોર પર બેઠેલા બ્લેક ડોગ.'},
#  {'en': 'Two giraffe standing next to each other near a wall.',
#   'gu': 'બે જિરાફ દિવાલની નજીક એકબીજા પાસે ઊભેલા છે.'},
#  {'en': 'A bird sitting on a branch of a tree.',
#   'gu': 'એક પક્ષી એક વૃક્ષની શાખા પર બેઠા.'},
#  {'en': 'A laptop computer screen with a tv in the background.',
#   'gu': 'પૃષ્ઠભૂમિમાં એક ટીવી સાથે એક લેપટોપ કમ્પ્યુટર સ્ક્રીન.'},
#  {'en': 'A pink bicycle leaning against a green railing next to a canal.',
#   'gu': 'એક નહેરની આગળ લીલી રેલિંગ સાથે ઝંઝાવાતી ગુલાબી સાયકલ.'},
#  {'en': 'A large white dog sits on a bench with people next to a path.',
#   'gu': 'મોટા શ્વેત કૂતરો એક પથ આગળના લોકો સાથે બેન્ચ પર બેસે છે.'},
#  {'en': 'A bus station that is loading the luggage for the bus.',
#   'gu': 'એક બસ સ્ટેશન જે બસ માટે સામાન લોડ કરી રહ્યું છે.'},
#  {'en': 'A airplane that is flying over a group of people.',
#   'gu': 'એક વિમાન જે લોકોના જૂથ ઉપર ઉડ્ડયન કરે છે.'},
#  {'en': 'A black and white dog chasing sheep in a field.',
#   'gu': 'એક કાળી અને સફેદ કૂતરો એક ક્ષેત્ર માં ઘેટાં પીછો.'},
#  {'en': 'a close up of two people on a bench with a dog',
#   'gu': 'એક કૂતરો સાથે બેન્ચ પર બે લોકો અપ બંધ'},
#  {'en': 'A man sitting on a bus with a bike in front of him.',
#   'gu': 'એક માણસ બસમાં તેની સામે એક બાઇક સાથે બેઠો.'},
#  {'en': 'A giraffe  standing on top of a dirt and grass field.',
#   'gu': 'એક જિરાફ ગંદકી અને ઘાસ ક્ષેત્રની ટોચ પર ઊભી છે.'},
#  {'en': 'Two giraffes eating leaves from a tall tree in a man made habitat.',
#   'gu': 'માણસના નિવાસસ્થાનમાં ઊંચા ઝાડમાંથી બે જિરાફ ખાવાથી.'},
#  {'en': 'A laptop that is sitting on a desk.',
#   'gu': 'એક લેપટોપ કે જે ડેસ્ક પર બેઠેલું છે'},
#  {'en': 'There is a green bus on a narrow street',
#   'gu': 'એક સાંકડી શેરી પર લીલા બસ છે'},
#  {'en': 'A bathroom showing the bathtub and the sink and mirror.',
#   'gu': 'સ્નાનગૃહ બાથટબ અને સિંક અને દર્પણ દર્શાવે છે.'},
#  {'en': 'A red bus parked at a bus stop in front of a building.',
#   'gu': 'બિલ્ડિંગની સામે બસ સ્ટોપ પર પાર્ક કરેલી લાલ બસ.'},
#  {'en': 'A red stop sign next to a road in the middle of nowhere.',
#   'gu': 'ક્યાંય મધ્યમાં રસ્તાની બાજુમાં એક લાલ સ્ટોપ સાઇન.'},
#  {'en': 'A red fire hydrant on a city street.',
#   'gu': 'શહેરની શેરીમાં લાલ આગ નળ.'},
#  {'en': 'a cat sitting in a bathroom sink looking at the floor.',
#   'gu': 'એક બાથરૂમ સિંકમાં બેઠેલા બિલાડી ફ્લોર પર જોઈ.'},
#  {'en': 'a bathroom decorated with some shelves and with a seperate bathtub and shower',
#   'gu': 'કેટલાક છાજલીઓથી શણગારવામાં બાથરૂમ અને અલગ બાથટબ અને ફુવારો'},
#  {'en': 'Two birds are sitting on the ledge of a deck.',
#   'gu': 'બે પક્ષીઓ ડેકની છાજલી પર બેસતા હોય છે.'},
#  {'en': 'A sign warning drivers that there are children at play.',
#   'gu': 'એક સંકેત ચેતવણી ડ્રાઇવર્સ કે જે નાટકમાં બાળકો છે.'},
#  {'en': 'A bus parked in front of a building.',
#   'gu': 'બિલ્ડિંગની સામે પાર્ક કરેલી બસ.'},
#  {'en': 'A young person in a motorcycle outfit sitting on a bike preparing to ride.',
#   'gu': 'એક મોટરસાઇકલ સરંજામ માં એક યુવાન વ્યક્તિ સવારી માટે તૈયાર બાઇક પર બેસીને.'},
#  {'en': 'A roll of toilet paper has been unspooled and torn',
#   'gu': 'શૌચાલય કાગળનો એક પત્ર સસ્પેન્ડ અને ફાટી ગયો છે'},
#  {'en': 'A boy is crossing the street in front of the buses.',
#   'gu': 'બસની સામે એક છોકરો શેરી પાર કરી રહ્યો છે.'},
#  {'en': 'A herd of giraffe standing on top of a dirt field.',
#   'gu': 'જિરાફની ટોળું એક ગંદકી ક્ષેત્રની ટોચ પર ઊભું છે.'},
#  {'en': 'A man with five running goats and a dog.',
#   'gu': 'પાંચ ચાલી બકરા અને એક કૂતરો સાથે એક માણસ'},
#  {'en': 'Two sheep lying in green grass have a surprised look for the camera.',
#   'gu': 'લીલા ઘાસમાં પડેલા બે ઘેટાં કેમેરા માટે આશ્ચર્યજનક દેખાવ ધરાવે છે.'},
#  {'en': 'The city bus is traveling down the road with its passengers.',
#   'gu': 'શહેરની બસ તેના મુસાફરો સાથે માર્ગ નીચે મુસાફરી કરી રહી છે.'},
#  {'en': 'Benches are casting shadows onto the side walk as a man rides a bike in the background.',
#   'gu': 'ન્યાયમૂર્તિઓ બાજુની ચાલ પર પડછાયા કાપી રહ્યા છે કારણ કે એક માણસ પૃષ્ઠભૂમિમાં બાઇક ચલાવે છે.'},
#  {'en': 'a kitchen with an electonic device above the sink ',
#   'gu': 'સિંક ઉપર એક ઇલેક્ટ્રોનિક ઉપકરણ સાથે રસોડું'},
#  {'en': 'A white apple computer and keyboard on desk.',
#   'gu': 'ડેસ્ક પર સફેદ સફરજનના કમ્પ્યુટર અને કીબોર્ડ.'},
#  {'en': 'A street corner with a store that shows open for 24 hour.',
#   'gu': '24 કલાક માટે ખુલ્લા બતાવે છે તે સ્ટોર સાથે એક શેરી ખૂણો'},
#  {'en': 'A school bus sits in a parking lot with other cars.',
#   'gu': 'સ્કૂલ બસ બીજી કાર સાથે પાર્કિંગની જગ્યા પર બેસે છે.'},
#  {'en': 'A bathroom with the toilet seat up beside the counter.',
#   'gu': 'કાઉન્ટરની બાજુમાં ટોઇલેટ સીટ સાથે બાથરૂમ.'},
#  {'en': 'a red bus that is parked next to a building',
#   'gu': 'એક લાલ બસ જે બિલ્ડિંગની બાજુમાં પાર્ક છે'},
#  {'en': 'There is a stop sign with another sign under it.',
#   'gu': 'તે હેઠળ અન્ય ચિહ્ન સાથે સ્ટોપ સાઇન છે'},
#  {'en': 'A bathroom with a large whirlpool style tub and a double vanity and mirrors.',
#   'gu': 'મોટી વમળ શૈલીના ટબ અને ડબલ મિથ્યાભિમાન અને અરીસાઓ સાથે બાથરૂમ.'},
#  {'en': 'A street sign sitting on the corner of a sidewalk.',
#   'gu': 'સાઈવૉકના ખૂણા પર બેઠા શેરી સાઇન.'},
#  {'en': 'A very simple bathroom with beige and cream colored decor.',
#   'gu': 'ન રંગેલું ઊની કાપડ અને ક્રીમ રંગીન સરંજામ સાથે ખૂબ જ સરળ બાથરૂમ.'},
#  {'en': 'A dog laying on the floor of a tiled hallway.',
#   'gu': 'એક ટાઈલ્ડ પરસાળ થતીના ભોંય પર ભરેલી કૂતરો.'},
#  {'en': 'Old train cars sit on a track in a train yard. ',
#   'gu': 'જૂની ટ્રેન કાર ટ્રેન યાર્ડના ટ્રેક પર બેસીને.'},
#  {'en': 'A person standing near a white toilet bowl ',
#   'gu': 'એક સફેદ શૌચાલયની વાટકી નજીક ઊભેલી વ્યક્તિ'},
#  {'en': 'a bathroom with a sink a mirror and drawers',
#   'gu': 'એક સિંક મિરર અને ટૂંકો જાંઘિયો સાથે બાથરૂમ'},
#  {'en': 'A juicer is used to make fresh orange juice. ',
#   'gu': 'તાજુ નારંગીનો રસ બનાવવા માટે જુઈઝરનો ઉપયોગ થાય છે.'},
#  {'en': 'An green army motorcycle parked behind a van.',
#   'gu': 'એક વાન પાછળ પાર્ક એક લીલા લશ્કર મોટરસાયકલ.'},
#  {'en': 'There is a dog sitting on the cart of a motorcycle.',
#   'gu': 'એક મોટરસાઇકલનાં કાર્ટ પર બેઠેલા કૂતરો છે.'},
#  {'en': 'A small bird sits on a branch in a tree.',
#   'gu': 'એક નાના પક્ષી એક વૃક્ષ એક શાખા પર બેસીને.'},
#  {'en': 'THERE ARE A LOT OF MOTOR BIKES ON THE GRASS',
#   'gu': 'ત્યાં ગ્રેસ પર મોટર બાઇટ્સ ઘણો છે'},
#  {'en': 'an owl sitting on a branch in a forest',
#   'gu': 'એક ઘુવડ જંગલમાં શાખા પર બેઠા'},
#  {'en': 'Two giraffes that are standing in the dirt.',
#   'gu': 'બે જિરાફ જે ધૂળમાં ઊભા છે.'},
#  {'en': 'Several cars parked in a lot in a city.',
#   'gu': 'શહેરમાં ઘણાં કાર પાર્ક છે'},
#  {'en': 'Many people walk and ride bikes on a bridge across a river.',
#   'gu': 'ઘણા લોકો એક નદી પાર પુલ પર બાઇક ચલાવે છે અને સવારી કરે છે.'},
#  {'en': 'A fire hydrant is on a street near buildings at night.',
#   'gu': 'આગ હાઈડ્રન્ટ રાત્રે ઇમારતોની નજીક શેરીમાં છે.'},
#  {'en': 'A white bird hangs upside down from a wire.',
#   'gu': 'એક સફેદ પક્ષી વાયરથી ઊલટું અટકી જાય છે.'},
#  {'en': 'A political figure is on the Television near the blue signs. ',
#   'gu': 'એક રાજકીય વ્યક્તિ વાદળી સંકેતોની નજીકના ટેલિવીઝન પર છે'},
#  {'en': 'there is a man and a woman that are riding a motorcycle',
#   'gu': 'એક માણસ અને એક સ્ત્રી છે જે મોટરસાઇકલ પર સવારી કરે છે'},
#  {'en': 'a couple of giraffes that are standing next to each other',
#   'gu': 'જિરાફ્સના એક દંપતિ જે દરેક અન્ય બાજુમાં ઉભા છે'},
#  {'en': 'A sign hanging from the side of a building advertising a store.',
#   'gu': 'એક દુકાન જાહેરાત જાહેરાત મકાન બાજુ માંથી અટકી એક સાઇન.'},
#  {'en': 'The man is holding two knives in his hands.',
#   'gu': 'માણસ તેના હાથમાં બે છરીઓ ધરાવે છે.'},
#  {'en': 'A little girl has a bag of chips and a boy is smiling at her',
#   'gu': 'એક નાની છોકરીને ચિપ્સની એક થેલી છે અને એક છોકરો તેના પર હસતાં છે'},
#  {'en': 'A small plane parked on top of a lush green field.',
#   'gu': 'એક હૂંફાળું લીલા ક્ષેત્રની ટોચ પર ઊભેલું એક નાના વિમાન.'},
#  {'en': 'A sign is attached to a building wall.',
#   'gu': 'એક નિશાની મકાન દિવાલ સાથે જોડાયેલ છે.'},
#  {'en': 'Some ducks swim in a muddy pond of water.',
#   'gu': 'કેટલાક બતક પાણીના ગંઠાયેલું તળાવમાં તરીને.'},
#  {'en': 'Two airplanes leave a trail of smoke as they ascend upwards. ',
#   'gu': 'બે એરોપ્લેન ધુમાડાના ટ્રાયલ છોડી દે છે કારણ કે તે ઉપર તરફ જાય છે'},
#  {'en': 'A large passenger jet flying through a cloudy sky.',
#   'gu': 'વાદળાંથી આકાશમાં ઉડ્ડયન કરતી મોટી પેસેન્જર જેટ'},
#  {'en': 'A bird walking in the grass near some water.',
#   'gu': 'એક પક્ષી કેટલાક પાણી નજીક ઘાસ માં વૉકિંગ.'},
#  {'en': 'A sidewalk going past many stores near a street.',
#   'gu': 'ગલી નજીક ઘણા સ્ટોર્સમાં જઈને એક સાઇડવૉક'},
#  {'en': 'A train traveling on a train track next to railway platform.',
#   'gu': 'રેલવે પ્લેટફોર્મની બાજુ ટ્રેન ટ્રેક પર મુસાફરી કરતા ટ્રેન.'},
#  {'en': 'A man holding a pirate coffee cup in his right hand.',
#   'gu': 'એક માણસ પોતાના જમણા હાથમાં ચાંચિયો કોફી કપ ધરાવે છે.'},
#  {'en': 'The view from a window of an enclosed staircase open to the air. ',
#   'gu': 'હવામાં ખુલ્લી બંધ દાદરની બારીમાંથી દૃશ્ય.'},
#  {'en': 'a cat laying down next to a bike tire',
#   'gu': 'એક બિલાડી ટાયર નીચે આગામી બિછાવે'},
#  {'en': 'A lady near some rocks during the daytime looking at the camera.',
#   'gu': 'કેમેરા જોઈ દિવસે દિવસ દરમિયાન કેટલાક ખડકો નજીક એક મહિલા.'},
#  {'en': 'A street devoid of traffic surrounded by tall buildings.',
#   'gu': 'ઊંચી ઇમારતોથી ઘેરાયેલા ટ્રાફિકથી મુક્ત શેરી.'},
#  {'en': 'A white and green bus driving down a street.',
#   'gu': 'શેરી નીચે એક સફેદ અને લીલા બસ ડ્રાઇવિંગ.'},
#  {'en': 'A red fire hydrant between two trees in front of a building.',
#   'gu': 'બિલ્ડિંગની સામે બે વૃક્ષો વચ્ચે લાલ આગ નળ.'},
#  {'en': 'A white bathroom with gray tiles with a tub, sink, and toilet ',
#   'gu': 'એક ટબ, સિંક અને શૌચાલય સાથે ગ્રે ટાઇલ્સ સાથે સફેદ બાથરૂમ'},
#  {'en': 'A giraffe bends to smeel the branches of a fallen tree.',
#   'gu': 'એક જિરાફ એક ઘટી વૃક્ષ શાખાઓ સ્મિત માટે bends.'},
#  {'en': 'A kitchen with white cupboards, a bowl of bananas, cookbooks, a blue teakettle and other sundries.',
#   'gu': 'સફેદ કબાટ, કેળાના બાઉલ, કુકબુક્સ, વાદળી ટીકટલી અને અન્ય સુન્ડ્રીઝ ધરાવતી રસોડું.'},
#  {'en': 'a number of people standing next to an elephant',
#   'gu': 'એક હાથી આગળ સ્થાયી લોકો સંખ્યાબંધ'},
#  {'en': 'A bus sitting on the side of a river on muddy ground.',
#   'gu': 'કાદવવાળું જમીન પર નદીની બાજુ પર બેઠા બસ.'},
#  {'en': 'An elegant bathroom features a tub, sink, mirror, and decorations. ',
#   'gu': 'એક ભવ્ય બાથરૂમમાં ટબ, સિંક, મિરર, અને શણગારનો સમાવેશ કરે છે.'},
#  {'en': "View of a public men's' room with a  cot on the side.",
#   'gu': 'સાર્વજનિક પુરુષોના રૂમની બાજુમાં એક ખાટલાવાળી રૂમ.'},
#  {'en': 'a close up of a train with graffiti written on it',
#   'gu': 'તેના પર લખેલી ગ્રેફિટી સાથેનું ટ્રેન બંધ કરવું'},
#  {'en': 'a bathroom with a black counter and a big mirror',
#   'gu': 'કાળી કાઉન્ટર અને મોટા અરીસો સાથે બાથરૂમ'},
#  {'en': 'A street with market door openings is empty.',
#   'gu': 'બજારના બારણુંના મુખ સાથેની શેરી ખાલી છે.'},
#  {'en': 'A very nice looking clean cut and contemporary styled wash basin.',
#   'gu': 'એક ખૂબ જ સરસ શોધી સ્વચ્છ કટ અને સમકાલીન રીતની વૉશ બેઝિન.'},
#  {'en': 'A man sits on a park bench and looks at the view.',
#   'gu': 'એક માણસ પાર્કની બેન્ચ પર બેસે છે અને દ્રશ્ય જુએ છે.'},
#  {'en': 'a painting hanging above the toilet displays a fancy picture',
#   'gu': 'એક શૌચાલય ઉપર અટકી પેઇન્ટિંગ ફેન્સી ચિત્ર દર્શાવે છે'},
#  {'en': 'A woman riding a bike with her baby on the back and German Shepard on leash.',
#   'gu': 'પીઠ પર તેના બાળક સાથે બાઇક ચલાવતી સ્ત્રી અને કાબાની પર જર્મન શેપર્ડ'},
#  {'en': 'Three tracks, one with a train,  follow contours of a hill.',
#   'gu': 'ત્રણ ટ્રેક, એક ટ્રેન સાથે, એક ટેકરીના રૂપરેખાઓનું પાલન કરે છે.'},
#  {'en': 'A motorcycle that is black in a room.',
#   'gu': 'એક મોટરસાઇકલ જે એક રૂમમાં કાળા છે.'},
#  {'en': 'A table set up with many various food and drink items.',
#   'gu': 'ઘણાં વિવિધ ખોરાક અને પીણા વસ્તુઓ સાથે એક ટેબલ સેટ.'},
#  {'en': 'A fire hydrant spilling water into a street near a fire truck.',
#   'gu': 'અગ્નિ ટ્રકની નજીકની શેરીમાં આગ નળના પાણીનો ફેલાવો.'},
#  {'en': 'Animals walk across a snowy field beneath puffy white clouds.',
#   'gu': 'પ્રાણીઓ પોચી સફેદ વાદળો નીચે બરફીલા ક્ષેત્ર તરફ જતા હોય છે.'},
#  {'en': 'Flamingos outside in a very grassy green area.',
#   'gu': 'ખૂબ ઘાસવાળો લીલા વિસ્તારની બહાર ફ્લેમિંગો.'},
#  {'en': 'A man sitting on a wooden bench playing a guitar in a park.',
#   'gu': 'એક બગીચામાં ગિટાર વગાડવા લાકડાની બેન્ચ પર બેસી રહેલો માણસ.'},
#  {'en': 'A water bird stands on a dock attached to a piling.  ',
#   'gu': 'એક પાણી પક્ષી એક ખૂંટો સાથે જોડાયેલ ગોદી પર રહે છે.'},
#  {'en': 'A  deep marble bathtub under an ornate mirror.',
#   'gu': 'અલંકૃત મિરર હેઠળ એક ઊંડા આરસ બાથટબ.'},
#  {'en': 'The two giraffes are standing next to each other. ',
#   'gu': 'બે જિરાફ એકબીજાની નજીક ઊભા છે.'},
#  {'en': 'A refrigerator and a table in a room.',
#   'gu': 'એક રૂમમાં રેફ્રિજરેટર અને ટેબલ.'},
#  {'en': 'A view of a sign that leads to Brooklyn and Queens.',
#   'gu': 'બ્રુકલિન અને ક્વીન્સ તરફ દોરી જાય છે તે નિશાનીના દૃષ્ટિકોણ.'},
#  {'en': 'This street pole has three street signs on it.',
#   'gu': 'આ શેરીમાં તેના પર ત્રણ શેરી ચિહ્નો છે.'},
#  {'en': 'A woman and two young children sit on a bench.',
#   'gu': 'એક સ્ત્રી અને બે નાના બાળકો બેન્ચ પર બેસીને.'},
#  {'en': 'A milky residue is at the bottom of the vase on the table.',
#   'gu': 'એક દૂધિયું શેષ ટેબલ પર ફૂલદાની તળિયે છે.'},
#  {'en': 'A row of motor scooters lined against a wall.',
#   'gu': 'મોટર સ્કૂટરની એક પંક્તિ દિવાલ સામે જતી હતી.'},
#  {'en': 'there are a few cows eating in this field ',
#   'gu': 'આ ક્ષેત્રમાં ખાવાથી થોડા ગાય છે'},
#  {'en': 'A bunch of goats standing on a podium',
#   'gu': 'એક પોડિયમ પર ઉભા બકરા એક ટોળું'},
#  {'en': 'Empty city street with multiple street signs on it. ',
#   'gu': 'તેના પર બહુવિધ શેરી ચિહ્નો સાથે ખાલી શહેરની શેરી.'},
#  {'en': 'Three giraffes huddled together watching a zebra and gazelle.',
#   'gu': 'ત્રણ જિરાફ્સ એક ઝેબ્રા અને ચપળ આંખોવાળું નાનું હરણ જોવાનું સાથે મળીને huddled'},
#  {'en': 'a traffic light in a big city with a building reflected in another buildings windows',
#   'gu': 'અન્ય ઇમારતોની વિંડોઝમાં પ્રતિબિંબિત બિલ્ડિંગ સાથે મોટા શહેરમાં ટ્રાફિક લાઇટ'},
#  {'en': 'A man in all black standing and staring. ',
#   'gu': 'બધા કાળા સ્થાયી અને staring એક માણસ.'},
#  {'en': 'A woman is standing next to a giraffe while holding its head ',
#   'gu': 'તેના માથાને હોલ્ડ કરતી વખતે જિરાફની બાજુમાં એક મહિલા ઊભી રહી છે'},
#  {'en': 'Pelicans  sit on vine like shrubbery under a blue sky.',
#   'gu': 'પેલિકન્સ વાદળી આકાશની જેમ ઝાડવાની જેમ વેલાઓ પર બેસે છે.'},
#  {'en': 'A giraffe standing alone next to some trees.',
#   'gu': 'કેટલાક ઝાડની બાજુમાં એકલા જિરાફ એકલો રહે છે.'},
#  {'en': 'Two bicycles are parked around a fire hydrant in front of a sidewalk cafe.',
#   'gu': 'સાઇડવૉક કાફેની સામે આગ હાઈડ્રન્ટની આસપાસ બે સાઈકલ પાર્ક છે'},
#  {'en': 'A street scene with cars and a stoplight.',
#   'gu': 'કાર અને સ્ટૉટલાઇટ સાથેનો એક શેરીનો દ્રશ્ય'},
#  {'en': 'A couple of giraffes are on a field by rocks and palm trees.',
#   'gu': 'જિરાફનો એક દંપતી ખડકો અને પામ વૃક્ષો દ્વારા એક ક્ષેત્ર પર છે'},
#  {'en': 'A herd of sheep and their sheep dog run in a pasture.',
#   'gu': 'ઘેટાંના ટોળાં અને ઘેટાંના કૂતરા એક ગોચરમાં ચાલે છે.'},
#  {'en': 'A view out a bus window of people riding bicycles.',
#   'gu': 'સાઇકલ સવારી લોકોની બસ વિંડો બહાર જુઓ'},
#  {'en': 'THERE IS A MOTOR BKE THAT IS ON DISPLAY ',
#   'gu': 'ત્યાં ડિસ્પ્લે પર છે કે મોટર બીકે છે'},
#  {'en': 'A pole at an intersection for a traffic light has birds all along the expanse.',
#   'gu': 'ટ્રાફિક લાઇટ માટે એક આંતરછેદ પરના ધ્રુવમાં અંતર સાથે પક્ષીઓ છે.'},
#  {'en': 'A group of people standing outside of a bus.',
#   'gu': 'બસની બહાર ઊભા રહેલા લોકોનો સમૂહ'},
#  {'en': 'A bunch of giraffes gathered around a feeding pole in a zoo.',
#   'gu': 'જિરાફ્સનો એક ટોળું ઝૂમાં ખવડાવવાના એક ભાગમાં ભેગા થયું.'},
#  {'en': 'A duck in a pond during a sunny day.',
#   'gu': 'સન્ની દિવસ દરમિયાન તળાવમાં ડક.'},
#  {'en': 'A train sitting on a track near other tracks.',
#   'gu': 'અન્ય ટ્રેક્સ નજીક એક ટ્રેક પર બેઠા ટ્રેન'},
#  {'en': 'An army jeep with an American Flag sitting at an airport.',
#   'gu': 'એરપોર્ટ પર બેઠેલા અમેરિકન ધ્વજ સાથે લશ્કર જીપ.'},
#  {'en': 'A couple of small birds and a building.',
#   'gu': 'નાના પક્ષીઓ અને એક મકાન દંપતિ.'},
#  {'en': 'The old woman is feeding the birds in the street.',
#   'gu': 'જૂની સ્ત્રી શેરીમાં પક્ષીઓને ખવડાવી રહી છે.'},
#  {'en': 'Liquid dark chocolate being poured over a white cake',
#   'gu': 'પ્રવાહી શ્યામ ચોકલેટ સફેદ કેક પર રેડવામાં આવે છે'},
#  {'en': 'A person sitting net to a TV on a sidewalk.',
#   'gu': 'સાઈડવોક પર ટીવી પર ચોખ્ખી બેઠેલા વ્યક્તિ.'},
#  {'en': 'A shot of a field and road taken from outside of a vehicle window.',
#   'gu': 'વાહન વિંડોની બહારથી લેવામાં આવેલા ક્ષેત્ર અને રસ્તાના શોટ.'},
#  {'en': 'A man sitting on a park bench reading the paper.',
#   'gu': 'કાગળ વાંચીને એક પાર્ક બેન્ચ પર બેસીને એક માણસ.'},
#  {'en': 'the signs on the post are warnings for vehicles.',
#   'gu': 'પોસ્ટ પરના સંકેતો વાહનો માટે ચેતવણીઓ છે.'},
#  {'en': 'A cityscape with several people holding signs protesting for a cause. ',
#   'gu': 'એક કારણ માટે વિરોધ ચિહ્નો હોલ્ડિંગ ઘણા લોકો સાથે શહેરી વસ્તી.'},
#  {'en': 'A plane that is flying over some trees.',
#   'gu': 'કેટલાક વૃક્ષો પર ઉડતી છે કે વિમાન.'},
#  {'en': 'A lush green field with horses standing on top of it.',
#   'gu': 'તેના ઉપર ઉભા રહેલા ઘોડા સાથે હૂંફાળું લીલા ક્ષેત્ર.'},
#  {'en': 'A clock has an image for Bicycle Cigarettes on it.',
#   'gu': 'એક ઘડિયાળ તેના પર સાયકલ સિગારેટ્સ માટે એક છબી ધરાવે છે.'},
#  {'en': 'An apartment jacuzzi bath with an expansive city view',
#   'gu': 'વિશાળ શહેર દૃશ્ય સાથે એક એપાર્ટમેન્ટમાં જાકુઝી બાથ'},
#  {'en': 'A traffic light in front of some business signs.',
#   'gu': 'કેટલાક વ્યવસાય સંકેતોની સામે ટ્રાફિક લાઇટ.'},
#  {'en': 'A street sign surrounded by beautiful potted flowers in bloom.',
#   'gu': 'મોર માં સુંદર potted ફૂલો દ્વારા ઘેરાયેલો એક શેરી સાઇન.'},
#  {'en': 'Double Decker bus stopping at a bus stop with people. ',
#   'gu': 'ડબલ ડેકર બસ લોકો સાથે બસ સ્ટોપ પર બંધ.'},
#  {'en': 'a microwave is built in to a all of a kitchen',
#   'gu': 'એક માઇક્રોવેવ એક રસોડું તમામ બાંધવામાં આવે છે'},
#  {'en': 'A giraffe eating from branches from high above.',
#   'gu': 'ઉપરના ઉચ્ચ શાખાઓમાંથી જિરાફ ખાવાથી.'},
#  {'en': 'A black bird sits in a flower boy.',
#   'gu': 'એક કાળા પક્ષી એક ફૂલ છોકરો બેસે છે.'},
#  {'en': 'A tram exiting the station with headlights on.',
#   'gu': 'એક ટ્રામ હેડલાઇટથી સ્ટેશનથી બહાર નીકળી રહ્યું છે.'},
#  {'en': 'A very old building with a clock in the tower. ',
#   'gu': 'ટાવરમાં એક ઘડિયાળ સાથે ખૂબ જૂના બિલ્ડિંગ.'},
#  {'en': 'A colorful blue bird perched on top of a persons arms.',
#   'gu': 'એક રંગીન વાદળી પક્ષી એક વ્યક્તિઓ હાથ ટોચ પર perched.'},
#  {'en': 'a person riding down a street on a motor cycle ',
#   'gu': 'એક મોટર ચક્ર પર શેરી નીચે સવારી એક વ્યક્તિ'},
#  {'en': 'Two mature women preparing food together in a kitchen.',
#   'gu': 'રસોડામાં ભોજનની તૈયારી કરતી બે પુખ્ત સ્ત્રીઓ'},
#  {'en': 'Two red benches sitting in front of windows.',
#   'gu': 'વિન્ડોની સામે બે લાલ બેન્ચ બેઠાં છે.'},
#  {'en': 'A man sitting on top of a bench near some pigeons.',
#   'gu': 'કેટલાક કબૂતરો નજીક એક બેન્ચ ઉપર બેઠા માણસ'},
#  {'en': 'a man wearing black is riding a red and silver motorcycle',
#   'gu': 'એક કાળો પહેરીને માણસ લાલ અને ચાંદીના મોટરસાયકલને સવારી કરે છે'},
#  {'en': 'A cat drinks water from a large water bowl.',
#   'gu': 'એક બિલાડી પાણીના મોટા બાઉલમાં પાણી પીવે છે'},
#  {'en': 'A light pole sitting next to the side of a road.',
#   'gu': 'રસ્તાની બાજુની બાજુમાં એક પ્રકાશ ધ્રુવ બેઠેલું.'},
#  {'en': 'A spotted glass bowl contains spoons and broccoli.',
#   'gu': 'એક સ્પોટેડ ગ્લાસ બાઉલમાં ચમચી અને બ્રોકોલીનો સમાવેશ થાય છે.'},
#  {'en': 'a bunch of cars and motorcycles parked on the side of the road ',
#   'gu': 'રસ્તાના બાજુ પર ઊભેલી કાર અને મોટરસાયકલોનો ટોળું'},
#  {'en': 'A long horn sheep with heavy wool on a grassy field.',
#   'gu': 'ઘાસવાળું ક્ષેત્ર પર ભારે ઊન સાથે લાંબી હોર્ન ઘેટાં'},
#  {'en': 'A cup of coffee with a small piece of melba toast on a table.',
#   'gu': 'ટેબલ પર મેલ્બા ટોસ્ટના નાનો ટુકડા સાથે કોફીનો એક કપ.'},
#  {'en': 'A red fire hydrant sitting on a brick sidewalk.',
#   'gu': 'એક ઇંટ સાઈડવોક પર બેઠા લાલ આગ નળ'},
#  {'en': 'A unique bookshelf is pictured that contains a lot of pots.',
#   'gu': 'એક અનન્ય બુકશેલ્ફ ચિત્રમાં છે જેમાં ઘણાં બધાં છે.'},
#  {'en': 'This is a picture of a white and black kitchen.',
#   'gu': 'આ એક સફેદ અને કાળી રસોડુંનું ચિત્ર છે.'},
#  {'en': 'This is an image of scooters and bicycles.',
#   'gu': 'આ સ્કૂટર અને સાયકલ્સની છબી છે'},
#  {'en': 'An orange and blue train car traveling past a forest.',
#   'gu': 'જંગલની મુસાફરી કરતા એક નારંગી અને વાદળી ટ્રેન કાર.'},
#  {'en': 'Tour bus with passengers on roadway during outdoor celebration.',
#   'gu': 'આઉટડોર ઉજવણી દરમિયાન રસ્તા પર મુસાફરો સાથે પ્રવાસ બસ'},
#  {'en': 'A motorcycle parked nest to rail near the ocean.',
#   'gu': 'એક મોટરસાઇકલ દરિયાની નજીક રેલ સુધી માળો બાંધતી હતી.'},
#  {'en': 'A lighted building and bricked street at night.',
#   'gu': 'રાત્રિના સમયે આયોજિત ઇમારત અને ભરાયેલા શેરી.'},
#  {'en': 'A street sign sitting in the middle of a road.',
#   'gu': 'રસ્તાના મધ્યમાં બેસીને એક શેરી સાઇન.'},
#  {'en': 'A black cat sitting on top of a toilet bowl seat cover.',
#   'gu': 'શૌચાલયની વાટકી સીટના કવરની ઉપર બેઠેલી કાળી બિલાડી.'},
#  {'en': 'A city intersection at Castro street with three stoplights',
#   'gu': 'ત્રણ સ્ટૉટલાઇટ્સ સાથે કાસ્ટ્રો સ્ટ્રીટમાં શહેરના આંતરછેદ'},
#  {'en': 'A herd of sheep are seen on a farm',
#   'gu': 'એક ઘેટાના ઘેટાં ખેતરમાં દેખાય છે'},
#  {'en': 'A train is parking on the bridge above the river.',
#   'gu': 'એક ટ્રેન નદી ઉપર પુલ પર પાર્કિંગ છે.'},
#  {'en': 'A man an a girl riding a motorcycle on a city street.',
#   'gu': 'એક માણસ એક છોકરી જે એક શહેરની શેરીમાં મોટરસાયકલ ચલાવે છે.'},
#  {'en': 'A man smiles while kneeling beside a miniature airplane.',
#   'gu': 'એક નાનું વિમાન સાથે બાજુમાં ઘૂંટણિયું કરતી વખતે માણસ સ્મિત થાય છે'},
#  {'en': 'Double-decker buses sit at the curb in front of an old building.',
#   'gu': 'ડબલ-ડેકર બસો જૂના બિલ્ડિંગની સામે કિનારે બેસીને.'},
#  {'en': 'Three people playing music sitting next to a mirror.',
#   'gu': 'મિરરની બાજુમાં બેસીને સંગીત વગાડતા ત્રણ લોકો.'},
#  {'en': 'Giraffes standing next to zebras on a lush green field.',
#   'gu': 'ગ્રીનહાઉસ લીલા પ્રદેશમાં ઝેબ્રાસની બાજુમાં ઊભા રહેલા જીરાફ્સ'},
#  {'en': 'A city street with a sign that says fun',
#   'gu': 'મજા કહે છે તે નિશાની સાથે શહેરની શેરી'},
#  {'en': 'A silver train on the train tracks between buildings.',
#   'gu': 'રેલવે પર ચાંદીની ટ્રેન ઇમારતો વચ્ચે ચાલે છે'},
#  {'en': 'A biker with a helmet on is standing behind two motorcycles.',
#   'gu': 'હેલ્મેટ પર બાઇકર બે મોટર સાયકલ પાછળ ઊભો છે.'},
#  {'en': 'Several people sitting on motorcycles that are not in motion.',
#   'gu': 'ગતિમાં ન હોય તેવા મોટરસાયકલો પર બેઠેલા કેટલાક લોકો.'},
#  {'en': 'A stop sign on a  country road is made to say something else. ',
#   'gu': 'દેશના રસ્તા પર એક સ્ટોપ સાઇન કંઈક બીજું કહેવામાં આવે છે'},
#  {'en': 'A couple of ducks float near a school of fish. ',
#   'gu': 'માછલીઓના એક સ્કૂપના નજીકના બે બતક ફ્લોટ કરે છે.'},
#  {'en': 'Two toilets in bathroom with various equipment and cords surrounding it.',
#   'gu': 'બાથરૂમમાં બે શૌચાલયો જેમાં વિવિધ સાધનો અને તેની આસપાસના કોર્ડ્સ છે.'},
#  {'en': 'a pizza that has a face made into it',
#   'gu': 'એક પિઝા જે તેને બનાવેલું ચહેરો છે'},
#  {'en': 'Three sheep grazing in a field with a few trees behind them',
#   'gu': 'તેમની પાછળ થોડાક વૃક્ષો સાથે ત્રણ ઘેટાં ચરાઈએ'},
#  {'en': 'a simple bathroom in beige with a toilet ',
#   'gu': 'શૌચાલય સાથે ન રંગેલું ઊની કાપડ એક સરળ બાથરૂમમાં'},
#  {'en': 'A small city bus with advertising on the side and back',
#   'gu': 'બાજુ પર અને પાછળ જાહેરાત સાથે એક નાની શહેર બસ'},
#  {'en': 'Two street signs on the side of a building.',
#   'gu': 'બિલ્ડિંગની બાજુમાં બે શેરી ચિહ્નો.'},
#  {'en': 'two men in in a white raft and a ship behind them',
#   'gu': 'બે માણસો સફેદ તરાપામાં અને તેમની પાછળ એક જહાજ'},
#  {'en': 'there is a one way street sign under a street name sign',
#   'gu': 'ગલી નામની નિશાની હેઠળ એક એકમાત્ર માર્ગ ચિહ્ન છે'},
#  {'en': 'a man that is nealed down in a bathroom',
#   'gu': 'એક બાથરૂમમાં નીચે નેલ કરવામાં આવેલો માણસ'},
#  {'en': 'A cocacola sign over a sidewalk area against a blue sky',
#   'gu': 'વાદળી આકાશની સામે એક સાઈડવોક વિસ્તારમાં કોકાકોલા સાઇન'},
#  {'en': 'A bird walking past a white car in a lot',
#   'gu': 'ઘણાં બધાં એક સફેદ કારની બાજુમાં ચાલતા પક્ષી'},
#  {'en': 'A street with many cars stopped at a traffic light.',
#   'gu': 'ઘણી કાર ટ્રાફિક લાઇટ પર બંધ થઈ ગઈ છે.'},
#  {'en': 'A toilet and a sink in small bathroom.',
#   'gu': 'નાના બાથરૂમમાં એક શૌચાલય અને સિંક.'},
#  {'en': 'A bird sitting on the branch of a pine tree.',
#   'gu': 'એક પાઇન વૃક્ષની શાખા પર બેઠા પક્ષી'},
#  {'en': 'A man riding a motorcycle on a race tracks.',
#   'gu': 'રેસ ટ્રેક્સ પર મોટરસાઇકલ ચલાવતી એક માણસ'},
#  {'en': 'Fire hydrant marked by a sign sitting in front of a cobblestone wall. ',
#   'gu': 'કોબબ્લેસ્ટોન દીવાલની આગળ બેસીને ચિહ્ન દ્વારા ચિહ્નિત થયેલ આગ હાઈડ્રન્ટ.'},
#  {'en': 'Image of a hat on a bed with the caption "Before The Wedding".',
#   'gu': '"ધ વેડિંગ પહેલાં" કૅપ્શન સાથે બેડ પરની ટોપીની છબી'},
#  {'en': 'A lone stop sign in a row of crypts',
#   'gu': 'ક્રિપ્ટ્સની પંક્તિમાં એકમાત્ર સ્ટોપ સાઇન'},
#  {'en': 'The airplane is parked on the runway in the airport.',
#   'gu': 'હવાઇમથક એરપોર્ટમાં રનવે પર પાર્ક થયેલું છે.'},
#  {'en': 'Street skateboarder doing aerial tricks as a bus passes.',
#   'gu': 'બસ પસાર થાય તે રીતે હવાઈ યુક્તિઓ કરી રહેલ સ્ટ્રીટ સ્કેટબોર્ડર.'},
#  {'en': 'There is a desktop computer on a desk and many photos and a deer head on the wall. ',
#   'gu': 'ડેસ્ક પર ડેસ્કટૉપ કમ્પ્યુટર છે અને દિવાલ પર ઘણા ફોટા અને હરણનું મથાળું છે.'},
#  {'en': 'A beautiful bird stands on the bank of a river.',
#   'gu': 'એક સુંદર પક્ષી નદીના કાંઠે રહે છે.'},
#  {'en': 'A bathroom with a white toilet next to a shower.',
#   'gu': 'સ્નાન કરવા માટે આગામી શૌચાલય ધરાવતું બાથરૂમ.'},
#  {'en': 'A man sits on the sidewalk next to a police motorcycle with a police officer in the background.',
#   'gu': 'એક માણસ પોલીસ મોટરસાઇકલની બાજુમાં સાઇડવૉક પર બેસે છે, જેમાં પૃષ્ઠભૂમિમાં પોલીસ અધિકારી છે.'},
#  {'en': 'an image of a kitchen setting with white appliances',
#   'gu': 'સફેદ ઉપકરણો સાથે રસોડામાં સેટિંગની છબી'},
#  {'en': 'A jetliner flying above in a light blue sky.',
#   'gu': 'હવામાં વાદળી આકાશમાં ઉપર ઉડતી જેટલાઇનર'},
#  {'en': 'A woman is preparing a blender on a counter.',
#   'gu': 'એક મહિલા કાઉન્ટર પર બ્લેન્ડર તૈયાર કરી રહી છે.'},
#  {'en': 'Skiers and people milling about a ski resort.',
#   'gu': 'સ્કી રિસોર્ટ વિશે સ્કીઅર્સ અને લોકો ભળી રહ્યાં છે.'},
#  {'en': 'A smiling woman in blue cleaning a white bathroom',
#   'gu': 'એક હૂંફાળું સ્ત્રી સફેદ બાથરૂમમાં સફાઈ કરે છે'},
#  {'en': 'A brick building has an almost full bike rack out front.',
#   'gu': 'ઈંટોની ઇમારતમાં ફ્રન્ટની લગભગ સંપૂર્ણ બાઇક રેક છે.'},
#  {'en': 'A kitchen area with a stove, cabinets and a refrigerator.',
#   'gu': 'સ્ટોવ, મંત્રીમંડળ અને રેફ્રિજરેટર સાથે એક રસોડું વિસ્તાર.'},
#  {'en': 'A large group of people in a very colorful van',
#   'gu': 'ખૂબ રંગીન વેનમાં લોકોનો મોટો સમૂહ'},
#  {'en': 'A person with a camera inside of a mirror in the bathroom.',
#   'gu': 'બાથરૂમમાં અરીસામાં કેમેરા ધરાવતી વ્યક્તિ.'},
#  {'en': 'A woman is looking over a ledge where a small bird is perched.',
#   'gu': 'એક સ્ત્રી એક છાજલી પર નજર રાખે છે જ્યાં એક નાનું પક્ષી રહે છે.'},
#  {'en': 'A container that has a packed lunch in it.',
#   'gu': 'એક કન્ટેનર જેમાં તેને ભરેલું લંચ હોય છે.'},
#  {'en': 'Two birds looking at their reflections in side mirror',
#   'gu': 'બાજુના દર્પણમાં તેમના પ્રતિબિંબેને જોતાં બે પક્ષીઓ'},
#  {'en': 'Sinks in the washroom that is public and white.',
#   'gu': 'શૌચાલયમાં સિંક જે જાહેર અને સફેદ હોય છે'},
#  {'en': 'A skateboarder performing a trick on a ramp while another one watches him.',
#   'gu': 'એક skateboarder એક રસ્તા પર યુક્તિ કરી જ્યારે અન્ય એક તેને જુએ છે'},
#  {'en': 'Seagull perched on a post near the water.',
#   'gu': 'સીગલ પાણીની નજીકના એક પોસ્ટ પર રહે છે.'},
#  {'en': 'A street corner flanked by a display board.',
#   'gu': 'એક ડિસ્પ્લે બોર્ડ દ્વારા flanked શેરી ખૂણે.'},
#  {'en': 'TWO ELECTRIC TRAIN COMPARTMENTS STANDING NEAR TO A BUILDING.',
#   'gu': 'બે ઇલેક્ટ્રીક ટ્રેઇન કમ્પાર્ટમેન્ટ્સ એક બિલ્ડિંગ નજીક સ્થાયી.'},
#  {'en': 'A turkey that is cooking in a large roaster oven on the counter. ',
#   'gu': 'એક ટર્કી કે જે કાઉન્ટર પર મોટી ભઠ્ઠીમાં ભઠ્ઠીમાં નાહવાનો કે તરવાનો પોશાક માં રસોઇ છે.'},
#  {'en': 'The cops in the city are riding horses threw the streets. ',
#   'gu': 'શહેરના કોપ્સ શેરીઓમાં સવારી કરી રહ્યા છે.'},
#  {'en': 'A commercial plane on the strip to take off.',
#   'gu': 'સ્ટ્રીપ પર વ્યાપારી વિમાન બંધ થવું.'},
#  {'en': 'a small sheep is standing in a pin',
#   'gu': 'એક નાની ઘેટા પિનમાં ઊભી છે'},
#  {'en': 'Trucks have arrived to get hte plane ready for departure.',
#   'gu': 'પ્રસ્થાન માટે એચટીઇએ તૈયાર થઈ જવા માટે ટ્રક્સ આવ્યા છે.'},
#  {'en': 'A white truck parked in a persons driveway',
#   'gu': 'વ્યક્તિઓના ડ્રાઇવ વેમાં પાર્ક કરાયેલી એક સફેદ ટ્રક'},
#  {'en': 'A full view of a kitchen with counters and table. ',
#   'gu': 'કાઉન્ટર્સ અને ટેબલ સાથે રસોડામાં સંપૂર્ણ દૃશ્ય.'},
#  {'en': 'A photo of a bench in the middle of the beach.',
#   'gu': 'બીચ મધ્યમાં એક બેન્ચ એક ફોટો.'},
#  {'en': 'Cars stopped on a road blocked by a herd of sheep.',
#   'gu': 'ઘેટાંના ઝાડ દ્વારા અવરોધેલા રસ્તા પર કાર અટકી.'},
#  {'en': 'A bird with a very long neck is standing in a tree.',
#   'gu': 'ખૂબ લાંબી ગરદન ધરાવતા પક્ષી એક વૃક્ષમાં ઉભા છે'},
#  {'en': 'a kitchen with a refrigerator a sink and cupboards',
#   'gu': 'એક રેફ્રિજરેટર સાથે એક રસોડું સિંક અને કબાટ'},
#  {'en': 'A bus is slowly approaching a fire hydrant. ',
#   'gu': 'એક બસ ધીમે ધીમે આગ નળના નજીક આવે છે.'},
#  {'en': 'A giraffe and a zebra in a zoo enclosure',
#   'gu': 'ઝૂ બિલ્ડીંગમાં જિરાફ અને ઝેબ્રા'},
#  {'en': 'Many pedestrians are walking across the city street.',
#   'gu': 'ઘણા પદયાત્રીઓ શહેરની શેરીમાં ફરતા હોય છે.'},
#  {'en': 'A traffic light that has a mirror on it.',
#   'gu': 'ટ્રાફિક લાઇટ જે તેના પર મિરર ધરાવે છે.'},
#  {'en': 'A train moves through a scenic, hilly landscape.',
#   'gu': 'એક ટ્રેન એક મનોહર, ડુંગરાળ લેન્ડસ્કેપથી ખસે છે.'},
#  {'en': 'A black and white photo of a bunch of people walking along a busy street.',
#   'gu': 'વ્યસ્ત ગલી સાથે ચાલતા લોકોના સમૂહનો એક કાળા અને સફેદ ફોટો.'},
#  {'en': 'A big white, yellow and grey kitchen with a stainless steel oven and microwave and sink.',
#   'gu': 'એક સ્ટેઈનલેસ સ્ટીલની પકાવવાની નાની ભઠ્ઠી અને માઇક્રોવેવ અને સિંક સાથે મોટું સફેદ, પીળો અને ભૂખરું રસોડું.'},
#  {'en': 'A double decker bus with neon lights at night.',
#   'gu': 'રાત્રિના સમયે નિયોન લાઇટ્સ સાથે ડબલ ડેકર બસ.'},
#  {'en': 'the person is using there foot to flush the toilet',
#   'gu': 'વ્યક્તિ શૌચાલયને ઉત્તેજીત કરવા માટે પગનો ઉપયોગ કરે છે'},
#  {'en': 'A man holding  camera with a hands free umbrella on his head.',
#   'gu': 'તેના માથા પર હાથ મુક્ત છત્ર ધરાવતી કેમેરા ધરાવતા માણસ.'},
#  {'en': 'A dog sits in the front seat of a jeep. ',
#   'gu': 'એક કૂતરો એક જીપની આગળની સીટમાં બેસે છે.'},
#  {'en': 'A row of sinks in a public restroom.',
#   'gu': 'જાહેર રેસ્ટરૂમમાં સિંકની એક પંક્તિ.'},
#  {'en': 'there is a man standing on a hill with sheep and two dogs',
#   'gu': 'એક ઘેટું અને બે કૂતરાં સાથે એક ટેકરી પર ઉભા માણસ છે'},
#  {'en': 'a kitchen that has some stoves in it',
#   'gu': 'એક રસોડું કે જેમાં તેમાં કેટલાક સ્ટૉવ છે'},
#  {'en': 'a woman pets a giraffe as other people look over the balcony ',
#   'gu': 'એક સ્ત્રી પાલતુ એક જિરાફ તરીકે અન્ય લોકો બાલ્કની પર જુઓ'},
#  {'en': 'A woman sitting on a bench overlooking a body of water.',
#   'gu': 'એક બોડી પર બેસીને બેઠેલી એક સ્ત્રી પાણીનું શરીર દેખાય છે.'},
#  {'en': 'Two sheep and one pig in a field like area',
#   'gu': 'વિસ્તાર જેવા ક્ષેત્રમાં બે ઘેટાં અને એક ડુક્કર'},
#  {'en': 'A small bathroom with the door half open leading to a toilet.',
#   'gu': 'એક શૌચાલય તરફ દોરી બારણું અડધા ખુલ્લા સાથે એક નાનું બાથરૂમ.'},
#  {'en': 'Three trains at a train station on parallel tracks.',
#   'gu': 'સમાંતર ટ્રેક પર ટ્રેન સ્ટેશન પર ત્રણ ટ્રેનો.'},
#  {'en': 'A International train station with a passenger train passing by.',
#   'gu': 'પસાર થતા પેસેન્જર ટ્રેન સાથેનું આંતરરાષ્ટ્રીય ટ્રેન સ્ટેશન.'},
#  {'en': 'Light blue door with windows next to a dilapidated building',
#   'gu': 'એક જર્જરિત મકાનની બાજુમાં વિન્ડોઝ સાથે આછો વાદળી દરવાજો'},
#  {'en': 'A bunch of cars sitting still in the middle of a street',
#   'gu': 'શેરીમાં મધ્યમાં હજુ પણ બેસી રહેલા કારનો ટોળું'},
#  {'en': 'A person sits on the sidewalk bench near a flock of birds.',
#   'gu': 'એક વ્યક્તિ પક્ષીઓના ટોળા નજીક સુતેલા બેન્ચ પર બેસીને.'},
#  {'en': 'a giraffe gallops through an open terrain ',
#   'gu': 'એક જિરાફ એક ખુલ્લા ભૂપ્રદેશ દ્વારા અટકી જાય છે'},
#  {'en': 'A man is standing near some cars and a bench.',
#   'gu': 'એક માણસ અમુક કાર અને એક બેન્ચ પાસે ઊભો છે.'},
#  {'en': 'A man in a black coat sitting on a bench at night.',
#   'gu': 'રાત્રે એક બેન્ચ પર બેઠેલા કાળા કોટમાં એક માણસ.'},
#  {'en': 'A bright street at night with several cars passing by.',
#   'gu': 'રાત્રે પસાર થતી ઘણી કાર સાથેની એક તેજસ્વી શેરી'},
#  {'en': 'A public bathroom with sinks, urinals, and toilet stalls.',
#   'gu': 'સિંક, મુતરડીઓ, અને શૌચાલયની દુકાનો સાથે જાહેર બાથરૂમ.'},
#  {'en': 'A motorcycle drives down a street near a couple of cars.',
#   'gu': 'એક મોટરસાઇકલ બે કારની નજીક એક ગલીની નીચે જાય છે.'},
#  {'en': 'A man is taking a picture of his bathroom sink.',
#   'gu': 'એક માણસ તેના બાથરૂમ સિંકનું ચિત્ર લઈ રહ્યું છે.'},
#  {'en': 'A smaller car is stopped at the red light, as traffic drives on. ',
#   'gu': 'એક નાની કાર લાલ લાઇટ પર બંધ થાય છે, કારણ કે ટ્રાફિક ડ્રાઈવો ચાલુ છે.'},
#  {'en': 'A woman holding and  kissing a black pet cat',
#   'gu': 'એક કાળી પાલતુ બિલાડી હોલ્ડિંગ અને ચુંબન કરતી સ્ત્રી'},
#  {'en': "Cuckoo clock ringing in the six o'clock hour.",
#   'gu': 'છ વાગ્યે કલાકમાં કોયલની ઘંટડી'},
#  {'en': 'Two people are preparing a meal in the kitchen.',
#   'gu': 'બે લોકો રસોડામાં ભોજન તૈયાર કરી રહ્યાં છે.'},
#  {'en': 'A plate of food with shrimp, pasta, and salad.',
#   'gu': 'ઝીંગા, પાસ્તા, અને કચુંબર સાથે ખોરાકની પ્લેટ.'},
#  {'en': 'A bench right next to some tall grass at the edge of a body of water.',
#   'gu': 'પાણીના એક ભાગની ધાર પર કેટલાક ઊંચા ઘાસની બાજુમાં બેન્ચ.'},
#  {'en': 'People getting on and off buses at a bus station.',
#   'gu': 'લોકો બસ સ્ટેશન પર બસમાં પ્રવેશી અને બંધ કરી રહ્યાં છે.'},
#  {'en': 'A large jet liner sitting on top of an airport tarmac.',
#   'gu': 'મોટા પાયે જેટ લાઇનર એરપોર્ટ ટર્મિકની ટોચ પર બેઠા છે.'},
#  {'en': 'A woman is standing in a fenced field near a cow. ',
#   'gu': 'એક સ્ત્રી ગાય નજીક એક ફેન્સીંગ ફીલ્ડમાં ઉભા છે'},
#  {'en': 'A squat toilet in the floor in a bathroom with gray tile.',
#   'gu': 'ગ્રે ટાઇલ સાથે બાથરૂમમાં ફ્લોરમાં બેસવું શૌચાલય.'},
#  {'en': 'Empty bar or lounge before or after business hours.',
#   'gu': 'વ્યવસાયના સમય પહેલા અથવા પછી ખાલી બાર અથવા લાઉન્જ.'},
#  {'en': 'There is two laptops on the table and bag on one of the chairs.',
#   'gu': 'ટેબલ પર બે લેપટોપ છે અને ચેરમાંના એક પર બેગ છે.'},
#  {'en': 'A stop sign in the woods on the corner of Geyer Springs',
#   'gu': 'ગેયર સ્પ્રિંગ્સના ખૂણા પર વૂડ્સમાં સ્ટોપ સાઇન'},
#  {'en': 'Two giraffes running in a sandy area with few trees.',
#   'gu': 'થોડા વૃક્ષો સાથે રેતાળ વિસ્તારમાં ચાલી બે જિરાફ.'},
#  {'en': 'A hotel bathroom has towels as well as a shower, mirror, and scale.',
#   'gu': 'એક હોટલ બાથરૂમમાં ટુવાલ તેમજ ફુવારો, મિરર અને સ્કેલ છે.'},
#  {'en': 'The wall of a building with an obsolete, old looking fire equipment box.',
#   'gu': 'એક કાલગ્રસ્ત, જૂના જોઈ આગ સાધનો બોક્સ સાથે બિલ્ડિંગની દીવાલ.'},
#  {'en': 'two giraffes running across a field in the mud',
#   'gu': 'કાદવમાં મેદાન પર બે જિરાફ ચાલી રહ્યા છે'},
#  {'en': 'A person is riding a boat through grassy water.',
#   'gu': 'એક વ્યક્તિ ઘાસવાળું પાણી દ્વારા બોટ ચલાવી રહ્યું છે.'},
#  {'en': 'A large bus parked in a street with a few people around it.',
#   'gu': 'તેની આસપાસના થોડાક લોકોની શેરીમાં એક મોટી બસ પાર્ક છે.'},
#  {'en': 'A group of people crossing a street next to a stop sign.',
#   'gu': 'એક સ્ટોપ સાઇન આગળ એક શેરી પાર લોકો એક જૂથ'},
#  {'en': 'A large white red and purple bus driving down a street.',
#   'gu': 'એક મોટી સફેદ લાલ અને જાંબલી બસ શેરીમાં નીચે ઉતરે છે.'},
#  {'en': 'A sink and mirror in a motel room.',
#   'gu': 'એક મોટેલ ઓરડામાં સિંક અને મિરર.'},
#  {'en': 'A city bus travelling on a street in a city.',
#   'gu': 'શહેરની શેરીમાં મુસાફરી કરતી શહેર બસ'},
#  {'en': 'Two signs that are on the side of a wall.',
#   'gu': 'દિવાલની બાજુમાં આવેલા બે ચિહ્નો.'},
#  {'en': 'a hydrant  well tired up placed at the middle of the town',
#   'gu': 'શહેરના મધ્યમાં સારી રીતે થાકેલા એક હાઇડન્ડ'},
#  {'en': 'A large plane on a landing strip surrounded by workers.',
#   'gu': 'કામદારો દ્વારા ઘેરાયેલો લેન્ડિંગ સ્ટ્રીપ પર એક વિશાળ વિમાન.'},
#  {'en': 'a cat with a big fluffy tail sitting on top of a car tire ',
#   'gu': 'એક કાર ટાયરની ટોચ પર બેસીને મોટી રુંવાટીવાળું પૂંછડીવાળી બિલાડી'},
#  {'en': 'a street sign with a building in the background',
#   'gu': 'પૃષ્ઠભૂમિમાં બિલ્ડિંગ સાથે શેરી સાઇન'},
#  {'en': 'a metal thing is sitting on top of a urinal',
#   'gu': 'ધાતુની વસ્તુ મુતરડીની ઉપર બેઠેલી છે'},
#  {'en': 'A laptop computer on a table and chair',
#   'gu': 'કોષ્ટક અને ખુરશી પર એક લેપટોપ કોમ્પ્યુટર'},
#  {'en': 'A motorcyclist sits on the ground next to his motorcycle in the middle of a road in a wooded area.',
#   'gu': 'એક મોટરસાઇકલ જંગલી વિસ્તારમાં એક રસ્તાની મધ્યમાં તેની મોટરસાઇકલની બાજુમાં જમીન પર બેસે છે.'},
#  {'en': 'Small dog with both a cat and a mouse riding on its back.',
#   'gu': 'એક બિલાડી અને માઉસ તેની પીઠ પર સવારી બંને સાથે નાના કૂતરો.'},
#  {'en': 'The words Market Street are written on a white sign.',
#   'gu': 'માર્કેટ સ્ટ્રીટ શબ્દ સફેદ સાઇન પર લખવામાં આવે છે.'},
#  {'en': 'Man in a crowd of people with a skateboard.',
#   'gu': 'સ્કેટબોર્ડ ધરાવતા લોકોની ભીડમાં માણસ'},
#  {'en': 'Two trains traveling paralell to one another on train tracks.',
#   'gu': 'ટ્રેન ટ્રેક પર એકબીજા સાથે પાર્લલની મુસાફરી કરતા બે ટ્રેનો'},
#  {'en': 'a stop sign a building cars bushes and trees',
#   'gu': 'એક સ્ટોપ એક મકાન કાર ઝાડ અને વૃક્ષો સાઇન ઇન કરો'},
#  {'en': 'A long line of bike racks next to a city street.',
#   'gu': 'એક શહેરની શેરી આગળ બાઇક રેક્સની એક લાંબી લાઇન.'},
#  {'en': 'Airplane at airport terminal getting ready to arrive or depart.',
#   'gu': 'એરપોર્ટ ટર્મિનલ પર વિમાન આવવા અથવા પ્રયાણ કરવા માટે તૈયાર છે.'},
#  {'en': 'A cop car parked in front of a white fire hydrant.',
#   'gu': 'એક સફેદ આગ નળ સામે પાર્ક એક કોપ કાર.'},
#  {'en': 'A couple sitting under an umbrella on a park bench.',
#   'gu': 'એક દંપતી પાર્ક બેન્ચ પર એક છત્ર હેઠળ બેસીને.'},
#  {'en': 'A cat wearing a santa hat scratching the air.',
#   'gu': 'હવાને ખંજવાળતી સાન્તા ટોટ પહેરીને એક બિલાડી.'},
#  {'en': 'A locomotive under an awning inside a building.',
#   'gu': 'એક મકાન અંદર ચંદરવો હેઠળ એક એન્જિનમોટિવ.'},
#  {'en': 'A brown dog is looking outside of the car window.',
#   'gu': 'ભુરો કૂતરો કાર વિંડોની બહાર જુએ છે'},
#  {'en': 'The motor cycle is parked near the curb.',
#   'gu': 'મોટર ચક્ર કિનારાની નજીક પાર્ક છે'},
#  {'en': 'A tablein a kichen with dishes and a canister on it.',
#   'gu': 'એક ટેબલિન, તેના પર વાનગીઓ અને એક ડબલું સાથે કિકેન.'},
#  {'en': 'a yellow white and blue jet is taking off',
#   'gu': 'એક પીળો સફેદ અને વાદળી જેટ બોલ લે છે'},
#  {'en': 'The wall has a couple of shelves on it.',
#   'gu': 'દીવાલ પર બે છાજલીઓ છે.'},
#  {'en': 'Two giraffe stand with their heads touching each other.',
#   'gu': 'બે જિરાફ તેમના માથા સાથે દરેક અન્ય સ્પર્શ સાથે ઊભા.'},
#  {'en': 'A man walking on a platform next to a train.',
#   'gu': 'ટ્રેનની બાજુના પ્લેટફોર્મ પર ચાલતા માણસ.'},
#  {'en': 'a sign on a fence with trees on the other side',
#   'gu': 'બીજી બાજુ પર વૃક્ષો સાથે વાડ પર એક નિશાની'},
#  {'en': 'A couple of women standing in a kitchen preparing food.',
#   'gu': 'રસોડામાં ખોરાક બનાવતી એક દંપતી સ્ત્રીઓ.'},
#  {'en': 'a traffic light on green that looks like it has the number seventy displayed',
#   'gu': 'તે ટ્રાફિક લાઇટ પર લીલો દેખાય છે જે તેના પર દેખાય છે તે સિત્તેર નંબર છે'},
#  {'en': 'A man in a brown shirt rides an elephant into the water.',
#   'gu': 'ભૂરા શર્ટનો માણસ પાણીમાં હાથીને સવારી કરે છે.'},
#  {'en': 'A white toilet and cup in a room.',
#   'gu': 'એક રૂમમાં સફેદ શૌચાલય અને કપ.'},
#  {'en': 'An intersection with street light poles and traffic sign poles. ',
#   'gu': 'સ્ટ્રીટ લાઇટ પોલ્સ અને ટ્રાફિક સાઇન પોલ્સ સાથેનું આંતરછેદ'},
#  {'en': 'An open laptop computer sitting on top of a desk.',
#   'gu': 'એક ખુલ્લા લેપટોપ કમ્પ્યુટર જે ડેસ્ક પર ટોચ પર છે'},
#  {'en': 'A man pulls a suitcase next to a train.',
#   'gu': 'એક માણસ ટ્રેનની બાજુમાં એક સુટકેસ ખેંચે છે.'},
#  {'en': 'A bird walking through the sand and looking for food.',
#   'gu': 'એક પક્ષી રેતીમાંથી પસાર થઇને અને ખોરાક શોધી રહી છે.'},
#  {'en': 'The bird stands on a hill near a large park.',
#   'gu': 'આ પક્ષી એક વિશાળ પાર્ક નજીક એક ટેકરી પર રહે છે.'},
#  {'en': 'A motorcycle that is sitting in the sand.',
#   'gu': 'એક મોટરસાઇકલ જે રેતીમાં બેસી રહી છે.'},
#  {'en': 'A woman is feeding a giraffe in a sandy plain. ',
#   'gu': 'એક સ્ત્રી રેતાળ સાદામાં જિરાફ ખવડાવી રહી છે.'},
#  {'en': 'A child sitting on a counter with some bananas.',
#   'gu': 'કેટલાક કેળા સાથે કાઉન્ટર પર બેસીને બાળક'},
#  {'en': 'There is no image on this page to describe.',
#   'gu': 'વર્ણન કરવા માટે આ પૃષ્ઠ પર કોઈ છબી નથી.'},
#  {'en': 'The two adult giraffe are standing very close together.',
#   'gu': 'બે પુખ્ત જિરાફ એકસાથે ખૂબ નજીક છે.'},
#  {'en': 'Two birds perched on rocks next to the ocean with a row of hotels in the background.',
#   'gu': 'બેકગ્રાઉન્ડમાં હોટલની એક પંક્તિ સાથે દરિયામાં આગામી બે ખડકો પર બે પક્ષીઓ રહે છે.'},
#  {'en': 'An old fashioned photo shows a large airplane and a small airplane. ',
#   'gu': 'જૂના જમાનાનું ફોટો મોટા એરપ્લેન અને નાના વિમાનને દર્શાવે છે.'},
#  {'en': 'a bed with some black bags on it',
#   'gu': 'તેના પર કેટલાક બ્લેક બેગ સાથે બેડ'},
#  {'en': 'A clock is shown on a wood panel.',
#   'gu': 'એક ઘડિયાળ લાકડું પેનલ પર બતાવવામાં આવે છે.'},
#  {'en': 'A bike parked in the middle of a meadow .',
#   'gu': 'ઘાસના મધ્યભાગમાં એક બાઇક પાર્ક.'},
#  {'en': 'a green bus is out on the road', 'gu': 'લીલા બસ રસ્તા પર છે'},
#  {'en': 'An old bathroom with a row of urinals.',
#   'gu': 'પેરેંટલની એક પંક્તિ સાથે જૂનું બાથરૂમ.'},
#  {'en': 'A woman walking a dog down a street.',
#   'gu': 'એક સ્ત્રી ગલી નીચે એક કૂતરો વૉકિંગ.'},
#  {'en': 'a man attaches a screen on a toilet seat ',
#   'gu': 'એક માણસ ટોઇલેટ સીટ પર સ્ક્રીનને જોડે છે'},
#  {'en': 'a very clean toilet with black and white tiles ',
#   'gu': 'કાળા અને સફેદ ટાઇલ્સ સાથે ખૂબ જ સ્વચ્છ શૌચાલય'},
#  {'en': 'A white and black cat laying on blanket on top of man.',
#   'gu': 'માણસની ટોચ પર ધાબળો પર મૂકતી સફેદ અને કાળી બિલાડી.'},
#  {'en': 'Two elderly people are sitting on a bench.',
#   'gu': 'બે વૃદ્ધ લોકો બેન્ચ પર બેઠા છે'},
#  {'en': 'The plane is flying over top of the cars',
#   'gu': 'આ વિમાન કારની ટોચ પર ઉડ્ડયન કરે છે'},
#  {'en': 'A woman in a blue dress with no shoes, seated with her legs crossed on a chair in the middle of a room.',
#   'gu': 'કોઈ પણ જૂતાની સાથે વાદળી ડ્રેસમાં સ્ત્રી, તેના પગથી બેઠેલી એક રૂમની મધ્યમાં ખુરશી પર ઓળંગી.'},
#  {'en': 'Blurry picture of a boy riding a bike through a grassy field near some cows',
#   'gu': 'કેટલાક ગાય નજીક એક ઘાસવાળો ક્ષેત્ર દ્વારા બાઇક ચલાવતી છોકરોની ઝાંખું ચિત્ર'},
#  {'en': 'There is a sink with a mirror and flowers on it',
#   'gu': 'તેના પર મિરર અને ફૂલો સાથે સિંક છે'},
#  {'en': 'A street sign with a bike leaned up against it.',
#   'gu': 'બાઇક સામેની એક સહી તેની સામે ઝઝૂમી રહી છે.'},
#  {'en': 'a bathroom with a mirror and a sink',
#   'gu': 'મિરર અને સિંક સાથે બાથરૂમ'},
#  {'en': 'A street pole with a yellow light and a no-walking sign.',
#   'gu': 'પીળો પ્રકાશ અને નો-વૉકિંગ સાઇન સાથે શેરીમાં પોલ.'},
#  {'en': 'A very long nice looking train by a platform.',
#   'gu': 'એક પ્લેટફોર્મ દ્વારા ખૂબ જ સરસ સરસ શોધી ટ્રેન.'},
#  {'en': 'a black and white dog a leash a windshield and a road',
#   'gu': 'એક કાળો અને સફેદ કૂતરો એક કાબૂમાં રાખવું અને વિન્ડશિલ્ડ અને રોડ'},
#  {'en': 'A couple of birds fly through a blue cloudy sky.',
#   'gu': 'કેટલાક પક્ષીઓ વાદળી વાદળા આકાશમાંથી પસાર થાય છે.'},
#  {'en': 'the bathroom has a toilet and a sink and mirror',
#   'gu': 'બાથરૂમમાં શૌચાલય અને સિંક અને મિરર છે'},
#  {'en': 'Fuzzy photo of two trains going to the same direction of two of many tracks.',
#   'gu': 'બે ટ્રેનોના અસ્પષ્ટ ફોટો, બે ટ્રેકના સમાન દિશામાં જતા.'},
#  {'en': 'A bunch of birds that are standing in the dirt.',
#   'gu': 'ધૂળમાં ઊભા રહેલા પક્ષીઓનો ટોળું.'},
#  {'en': 'The top of a steeped church building with clocks and small windows.  ',
#   'gu': 'ઘડિયાળો અને નાના વિન્ડોઝ સાથે પલાળવાળું ચર્ચ મકાનની ટોચ.'},
#  {'en': 'A bathroom in a house with a white color scheme',
#   'gu': 'એક સફેદ રંગ યોજના સાથેના ઘરમાં બાથરૂમ'},
#  {'en': 'A train that is on the tracks inside of a building.',
#   'gu': 'એક ટ્રેન કે જે બિલ્ડિંગની અંદરના ટ્રેક પર છે.'},
#  {'en': 'Two motorcycles parked near each other by a sewer',
#   'gu': 'ગટર દ્વારા એકબીજા નજીક બે મોટરસાઇકલ્સ પાર્ક'},
#  {'en': 'many people and snowboards at the bottom of a snowy mountain',
#   'gu': 'ઘણા લોકો અને બરફીલા પર્વત તળિયે સ્નોબોર્ડસ'},
#  {'en': 'A car show features a yellow hot wheels car.',
#   'gu': 'કાર શો પીળા હોટ વ્હીલ્સ કાર આપે છે.'},
#  {'en': 'Two giraffes lying together in a grassy field.',
#   'gu': 'ઘાસના મેદાનમાં બે જિરાફ એકબીજા સાથે જોડાયેલા છે.'},
#  {'en': 'A blue park bench painted blue sits on a blue sidewalk.',
#   'gu': 'બ્લુ પાર્ક બેન્ચ પેઇન્ટેડ વાદળી વાદળી સાઇડવેક પર બેસે છે.'},
#  {'en': 'Two men are sitting on a wooden crate with a cow next to them.',
#   'gu': 'બે માણસો એક લાકડાના થાંભલા પર બેસતા હોય છે.'},
#  {'en': 'A man gently attempts to feed a baby bird. ',
# ...
#   'gu': 'બે લોકો ઉજવણીમાં કેકમાં કાપતા હોય છે.'},
#  {'en': 'yellow lines painted on city street at night',
#   'gu': 'રાત્રે શહેરની શેરી પર દોરવામાં આવેલી પીળા રેખાઓ'},
#  {'en': 'A toilet in a bathroom with black and white tiles on the floor.',
#   'gu': 'ફ્લોર પર કાળા અને સફેદ ટાઇલ્સ સાથે બાથરૂમમાં એક શૌચાલય.'},
#  {'en': 'A stoplight on the side of the road.',
#   'gu': 'રસ્તાના બાજુ પર સ્ટોપલાઇટ'},
#  {'en': 'A dark shot of a building on a street at night',
#   'gu': 'રાત્રિના સમયે શેરીમાં બિલ્ડિંગનો ડાર્ક શોટ'},
#  {'en': 'An air traffic controller directing an airplane on a busy runway.',
#   'gu': 'એર ટ્રાફિક નિયંત્રક એક વ્યસ્ત રનવે પર વિમાનને દિગ્દર્શન કરે છે.'},
#  {'en': 'A stoplight hangs over an intersection in the city.  ',
#   'gu': 'શહેરમાં આંતરછેદ પર સ્ટોપલાઈટ અટકી જાય છે.'},
#  {'en': 'These gentlemen are looking at something of great interest to them.',
#   'gu': 'આ સજ્જનોની તેમની તરફેણમાં રસ દાખવતા હોય છે.'},
#  {'en': 'there is a stop sign and a street sign at the corner ',
#   'gu': 'ખૂણા પર સ્ટોપ સાઇન અને શેરીનું ચિહ્ન છે'},
#  {'en': 'A giraffe bending over while standing on green grass.',
#   'gu': 'ગ્રીન ગ્રાસ પર ઉભા કરતી વખતે જિરાફ ઉપર બેન્ડિંગ'},
#  {'en': 'a boat is sitting out of the water at the beach',
#   'gu': 'એક હોડી સમુદ્રમાં પાણીથી બેસી રહી છે'},
#  {'en': 'A child places his hands on the head and neck of a sheep while another sheep looks at his face.',
#   'gu': 'એક બાળક ઘેટાનું માથું અને ગરદન પર હાથ રાખે છે જ્યારે બીજી ઘેટાં તેના ચહેરા પર દેખાય છે.'},
#  {'en': 'Two skiers wearing backpacks in a snow storm.',
#   'gu': 'બરફના તોફાનમાં બે સ્કાયર્સ પહેર્યા'},
#  {'en': 'A seagull standing on a beach with a dwindling tide',
#   'gu': 'એક સીગલ એક ઘટ્ટ ભરતી સાથે બીચ પર ઉભા છે'},
#  {'en': 'a bathroom that has a sink and some lights',
#   'gu': 'બાથરૂમ કે જેમાં સિંક અને કેટલાક લાઇટ હોય છે'},
#  {'en': 'A hill of a street at a stoplight with traffic ',
#   'gu': 'ટ્રાફિક સાથે સ્ટોપલાઇટ પર શેરીની એક ટેકરી'},
#  {'en': 'A bathroom scene with a sink, shower, and a toilet.',
#   'gu': 'સિંક, સ્નાન અને શૌચાલય સાથે બાથરૂમ દ્રશ્ય.'},
#  {'en': 'A traffic light is red near a building with windows.',
#   'gu': 'ટ્રાફિક લાઇટ વિન્ડો સાથે બિલ્ડિંગની નજીક લાલ છે.'},
#  {'en': 'A couple of sheep standing on top of snow covered ground.',
#   'gu': 'બરફના ઢોળેલા જમીન ઉપર ઊભેલા ઘેટાં એક દંપતી.'},
#  {'en': 'A plate of food placed next to a computer.',
#   'gu': 'કમ્પ્યૂટરની બાજુમાં આવેલા ખોરાકની પ્લેટ.'},
#  {'en': 'A woman in a large empty air plane next to a bed.',
#   'gu': 'એક બેડ નીચે આગામી એક વિશાળ ખાલી હવા વિમાનમાં એક મહિલા.'},
#  {'en': 'a dog watching a little boy on tv',
#   'gu': 'એક ટીવી પર થોડો છોકરો જોવા કૂતરો'},
#  {'en': 'A very clean toilet with the lid up next to toilet paper. ',
#   'gu': 'ટોઇલેટ કાગળની બાજુમાં ઢાંકણ સાથે ખૂબ સ્વચ્છ શૌચાલય.'},
#  {'en': 'The brown eagle is soaring over the ocean.',
#   'gu': 'ભૂરા ગરુડ સમુદ્ર પર ઊડતા છે.'},
#  {'en': 'A woman stands in a small kitchenette area.',
#   'gu': 'એક મહિલા નાના કિચનનાં વિસ્તારમાં રહે છે.'},
#  {'en': 'Giraffes entering and exiting a building and grazing in a fenced area',
#   'gu': 'એક ફેન્સીંગ વિસ્તારમાં મકાન અને ચરાઈમાં પ્રવેશતા અને બહાર નીકળતા ગિરફાઝ'},
#  {'en': 'two people holding signs near a building with a sky background',
#   'gu': 'સ્કાય બેકગ્રાઉન્ડ સાથે બિલ્ડિંગ નજીકના બે લોકો હોલ્ડિંગ સંકેતો'},
#  {'en': 'A train coming down the tracks arriving at a station.',
#   'gu': 'સ્ટેશન પર આવતી ટ્રેનો નીચે આવતી ટ્રેન.'},
#  {'en': 'A museum showing old things used several hundred years ago that is roped off.',
#   'gu': 'એક સંગ્રહાલય જે જૂની વસ્તુઓનો ઉપયોગ કરે છે તે ઘણા વર્ષો પહેલાં વપરાય છે.'},
#  {'en': 'An old man is wearing an odd hat',
#   'gu': 'એક વૃદ્ધ માણસ વિચિત્ર ટોપી પહેરી રહ્યો છે'},
#  {'en': 'A man with a white-painted face and a bananas on his head. ',
#   'gu': 'તેના માથા પર એક શ્વેત પેઇન્ટેડ ચહેરો અને કેળા ધરાવતો માણસ.'},
#  {'en': 'Two men in blazers and fedoras with a moped in the background.',
#   'gu': 'પૃષ્ઠભૂમિમાં મોપેડ સાથે બ્લેઝર્સ અને ફેડોરાસમાં બે પુરૂષો.'},
#  {'en': 'Two lamp posts are shown on a street corner.',
#   'gu': 'બે દીવોની પોસ્ટ્સ શેરી ખૂણા પર દર્શાવવામાં આવે છે.'},
#  {'en': 'A red fire hydrant is on a leafy sidewalk.',
#   'gu': 'એક લાલ આગ નળ પાંદડાવાળા સાઇડવેક પર છે'},
#  {'en': 'A lone duck swimming in the grey green water of a marsh.',
#   'gu': 'માર્શના ગ્રે લીલા પાણીમાં એકલા ડક સ્વિમિંગ.'},
#  {'en': 'Building with store name and antiques in front. ',
#   'gu': 'આગળ સ્ટોર નામ અને પ્રાચીન વસ્તુઓ સાથે મકાન.'},
#  {'en': 'The lady is sitting on the bench holding her handbag.',
#   'gu': 'આ મહિલા બેન્ડ પર બેસતી હોય છે.'},
#  {'en': 'a model train set on a table with farm scene next to it ',
#   'gu': 'ટેબલ પર એક મોડેલ ટ્રેન, જે તેની આગળ ફાર્મ દ્રશ્ય છે'},
#  {'en': 'a train on a train track near hills ',
#   'gu': 'ટેકરીઓ નજીક એક ટ્રેન ટ્રેક પર એક ટ્રેન'},
#  {'en': 'A group of old planes on display in a museum',
#   'gu': 'મ્યુઝિયમમાં પ્રદર્શનમાં જૂના વિમાનોનું એક જૂથ'},
#  {'en': 'A young man is carrying his surf board on the beach.',
#   'gu': 'એક યુવાન માણસ બીચ પર તેના સર્ફ બોર્ડ વહન છે.'},
#  {'en': 'The keyboard has an external monitor cooked up to it.',
#   'gu': 'કિબોર્ડ પાસે એક બાહ્ય મોનિટર છે જેની ઉપર રાંધવામાં આવે છે.'},
#  {'en': 'A small cute clock by some other beaten up looking things.',
#   'gu': 'કેટલાક અન્ય કોઈ રન નોંધાયો નહીં જોઈ વસ્તુઓ દ્વારા એક નાનું સુંદર ઘડિયાળ'},
#  {'en': 'A group of people walking across a street below a tall building.',
#   'gu': 'ઊંચા બિલ્ડિંગ નીચે શેરીમાં ચાલતા લોકોનો સમૂહ.'},
#  {'en': 'a large airplane that is on a runway',
#   'gu': 'મોટા વિમાન કે રનવે પર છે'},
#  {'en': 'A woman is standing in her kitchen posing for a photo. ',
#   'gu': 'એક ફોટો તેના ફોટોમાં દર્શાવતી એક મહિલા છે.'},
#  {'en': 'The street sign for Jack Kerouac (Adler) ',
#   'gu': 'જેક કેરોક (એડલર) માટેનો શેરીનો સંકેત'},
#  {'en': 'A kitchen with food cooking on the range and in the oven.',
#   'gu': 'શ્રેણી અને પકાવવાની નાની ભઠ્ઠીમાં ખોરાક રસોઈ સાથેના રસોડું.'},
#  {'en': 'A mother duck with her ducklings in a pond. ',
#   'gu': 'એક તળાવમાં એક ડકની સાથે માતા બતક.'},
#  {'en': 'A motorcycle policeman is smiling at the photographer.',
#   'gu': 'એક મોટરસાઇકલ પોલીસકર્મે ફોટોગ્રાફર પર હસતાં છે.'},
#  {'en': 'some people standing at the top of some stairs ',
#   'gu': 'કેટલીક સીડીની ટોચ પર ઊભેલા કેટલાક લોકો'},
#  {'en': "A small and clean bathroom thanks is in someone's house. ",
#   'gu': 'એક નાનાં અને સ્વચ્છ બાથરૂમમાં આભાર કોઈના ઘરે છે.'},
#  {'en': 'A street sign leaned over with the words High Gate Avenue on it.',
#   'gu': 'તેના પર હાઇ ગેટ એવન્યુના શબ્દો સાથે શેરી સાઇન પર ઝુકાવ્યો.'},
#  {'en': 'A open door in a small kitchen room.',
#   'gu': 'નાના રસોડામાં રૂમમાં એક ખુલ્લું બારણું.'},
#  {'en': 'A dog dressed in a biker costume on a small bike.',
#   'gu': 'એક નાના બાઇક પર એક બાઇકર કોસ્ચ્યુમ પોશાક પહેર્યો કૂતરો.'},
#  {'en': 'Police officer standing in front of a public transportation bus. ',
#   'gu': 'જાહેર પરિવહન બસની સામે ઊભેલા પોલીસ અધિકારી.'},
#  {'en': 'A bird is sitting next to the tree.',
#   'gu': 'એક પક્ષી વૃક્ષની બાજુમાં બેઠેલું છે.'},
#  {'en': 'A red plate topped with a chocolate pastry.',
#   'gu': 'એક લાલ પ્લેટ ચોકલેટ પેસ્ટ્રી સાથે ટોચ પર છે'},
#  {'en': 'A bus driving down a street next to buildings.',
#   'gu': 'ઇમારતોની બાજુમાં એક શેરી નીચે બસ ચલાવતી હતી'},
#  {'en': 'The birds are eagerly waiting for their food to arrive.',
#   'gu': 'પક્ષીઓ ઉત્સુકતાથી તેમના ખોરાક આવવા માટે રાહ જોઈ રહ્યા છે'},
#  {'en': 'A giraffe is standing near some large boulders.',
#   'gu': 'એક જિરાફ કેટલાક મોટા પથ્થરની નજીક ઉભા છે.'},
#  {'en': 'White truck parked on street with trees and man',
#   'gu': 'સફેદ ટ્રક વૃક્ષો અને માણસ સાથે શેરી પર પાર્ક'},
#  {'en': 'A man is standing on top of the engine car of a train.',
#   'gu': 'ટ્રેનની એન્જિન કારની ટોચ પર એક માણસ ઊભો છે'},
#  {'en': 'these are two tall giraffes eating from trees',
#   'gu': 'આ ઝાડમાંથી ખાવાથી બે ઊંચા જિરાફ છે'},
#  {'en': 'Man sitting on toilet top holding hat and cigarette',
#   'gu': 'ટોઇલેટ ટોચે હોલ્ડિંગ ટોપી અને સિગારેટ પર બેઠા માણસ'},
#  {'en': 'Downtown seems is really quiet for the night night',
#   'gu': 'ડાઉનટાઉન રાત્રે રાત્રે માટે ખરેખર શાંત છે'},
#  {'en': 'A motorcycle is parked on the beach near the ocean.',
#   'gu': 'એક મોટરસાઇકલ દરિયાની નજીકના બીચ પર ઊભી છે'},
#  {'en': 'a few cars that are stopped by some lights',
#   'gu': 'કેટલાક લાઇટ કે જે કેટલાક લાઇટ દ્વારા અટકાવાયેલ છે'},
#  {'en': 'An old style kitchen with baby blue cabinets.',
#   'gu': 'બાળક વાદળી કેબિનેટ્સ સાથેની એક જૂની શૈલી રસોડું.'},
#  {'en': 'A row of motorcycles parked next to each other.',
#   'gu': 'મોટરસાયકલોની હરોળ દરેક અન્ય આગળ પાર્ક કરે છે.'},
#  {'en': 'This woman is standing next to her bike.',
#   'gu': 'આ સ્ત્રી તેના બાઇકની આગળ ઊભી છે'},
#  {'en': 'some benches sitting by a clear lake ',
#   'gu': 'સ્પષ્ટ તળાવથી બેસીને કેટલાક પાટલીઓ'},
#  {'en': 'A Giraffe standing near some rocks  on the grass',
#   'gu': 'એક જીરાફ ઘાસ પર કેટલાક ખડકો નજીક ઊભા છે'},
#  {'en': 'A person and a toilet standing in a room.',
#   'gu': 'એક વ્યક્તિ અને એક રૂમમાં એક ટોઇલેટની ઉભા છે.'},
#  {'en': 'A toilet with a hammer on it in a small room.',
#   'gu': 'એક નાના ઓરડામાં તેના પર ધણ સાથે શૌચાલય.'},
#  {'en': 'Two people board a city bus holding surfboards.',
#   'gu': 'બે લોકો સર્ફબોર્ડ્સ ધરાવતી સિટી બસ ચલાવે છે.'},
#  {'en': 'Many people are busy together in a messy kitchen.',
#   'gu': 'ઘણાં લોકો એક અવ્યવસ્થિત રસોડામાં એકસાથે વ્યસ્ત છે.'},
#  {'en': 'A table sits in front of the bar area of a wall.',
#   'gu': 'એક કોષ્ટક દિવાલના બાર વિસ્તારની સામે આવેલું છે.'},
#  {'en': 'An empty bench at a transportation station, train or airport setting.',
#   'gu': 'પરિવહન સ્ટેશન, ટ્રેન અથવા એરપોર્ટ સેટિંગ પર એક ખાલી બેન્ચ.'},
#  {'en': 'A black and white shot of a city with a tall skyscraper in the distance.',
#   'gu': 'અંતર માં એક ઊંચા ગગનચુંબી ઈમારત સાથે એક શહેરના કાળા અને સફેદ શૉટ.'},
#  {'en': 'Pair of small planes flying near each other on stormy day.',
#   'gu': 'તોફાની દિવસ પર દરેક અન્ય નજીક ઉડ્ડયન નાના વિમાનોની જોડી.'},
#  {'en': 'A red double decker tourist bus goes around town',
#   'gu': 'એક લાલ ડબલ ડેકર પ્રવાસી બસ નગરની આસપાસ જાય છે'},
#  {'en': 'Several cars and people at bikes sitting at a red light.',
#   'gu': 'બાઇક પર કેટલાક કાર અને લોકો લાલ પ્રકાશમાં બેઠા.'},
#  {'en': 'A desk with two laptops and a computer on it. ',
#   'gu': 'તેના પર બે લેપટોપ અને એક કમ્પ્યૂટર સાથે ડેસ્ક.'},
#  {'en': 'A black dog with a red collar is drinking out of a toilet bowl.',
#   'gu': 'લાલ કાળા સાથેનો કાળો કૂતરો શૌચાલયની બાઉલમાંથી પીવાનું છે.'},
#  {'en': 'Protesters hold up signs next to a busy street.',
#   'gu': 'વિરોધીઓ વ્યસ્ત શેરીની બાજુમાં સંકેતો ધરાવે છે'},
#  {'en': 'A lot of cars are causing a traffic jam.',
#   'gu': 'ઘણી કાર ટ્રાફિક જામનું કારણ છે.'},
#  {'en': 'Two giraffes standing under a tree in front of some large rocks.',
#   'gu': 'કેટલાક મોટા ખડકોની સામે ઝાડ નીચે ઊભેલા બે જિરાફ.'},
#  {'en': 'A small van painted in silver glitter paint parked next to a double decker bus.',
#   'gu': 'ડબલ ડેકર બસની બાજુમાં પાર્ક ચાંદીના ઝગમગાટ પેઇન્ટમાં દોરવામાં આવેલી નાની વાન.'},
#  {'en': 'A young man is riding his skateboard past a construction zone.',
#   'gu': 'એક યુવાન માણસ પોતાના સ્કેટબોર્ડને એક બાંધકામ ઝોનની પાછળ સવારી કરે છે.'},
#  {'en': 'A double street sign at a neighbourhood corner.',
#   'gu': 'પડોશી ખૂણા પર ડબલ સ્ટ્રીટ સાઇન.'},
#  {'en': 'A train that is yellow is moving down the tracks.',
#   'gu': 'એક ટ્રેન પીળો છે જે ટ્રેકને નીચે ખસેડી રહી છે.'},
#  {'en': 'a very busy street with people and cars',
#   'gu': 'લોકો અને કાર સાથે ખૂબ વ્યસ્ત શેરી'},
#  {'en': 'A beach front with buildings and park benches nearby.',
#   'gu': 'નજીકમાં ઇમારતો અને પાર્ક બેન્ચ સાથે એક બીચ ફ્રન્ટ.'},
#  {'en': 'Silver and red airplane flying through the air alone. ',
#   'gu': 'સિલ્વર અને લાલ વિમાન એકલા હવા મારફતે ઉડ્ડયન.'},
#  {'en': 'A dining room with hard wood floors that is very fancy. ',
#   'gu': 'હાર્ડ લાકડાના માળ સાથે ડાઇનિંગ રૂમ જે ખૂબ ફેન્સી છે.'},
#  {'en': 'Four traffic lights pointing in all different directions.',
#   'gu': 'ચાર અલગ અલગ દિશામાં નિર્દેશ કરતી ચાર ટ્રાફિક લાઇટ.'},
#  {'en': 'A man is standing on the runway beside a parked airplane.',
#   'gu': 'એક માણસ પાર્ક એરપ્લેનની બાજુમાં રનવે પર ઊભો છે.'},
#  {'en': 'A close up of the middle section of a bicycle.',
#   'gu': 'એક સાયકલ મધ્ય ભાગમાં બંધ કરો.'},
#  {'en': 'A group of people who are outside of a building.',
#   'gu': 'બિલ્ડિંગની બહારના લોકોનો સમૂહ.'},
#  {'en': 'A yellow taxi on a city street corner with a couple of people talking to the driver.',
#   'gu': 'ડ્રાઇવર સાથે વાત કરતા લોકો સાથે શહેરની શેરી ખૂણા પર પીળા ટેક્સી.'},
#  {'en': 'Small yellow plane with red, white and blue stripes, parked with mechanic checking it out.',
#   'gu': 'લાલ, સફેદ અને વાદળી પટ્ટાઓવાળા નાના પીળી વિમાન, મિકેનિકને તેની તપાસ કરીને પાર્ક કરે છે.'},
#  {'en': 'A bus pulls up to a bus stop on the road.',
#   'gu': 'બસ રસ્તા પર બસ સ્ટોપ સુધી ખેંચે છે.'},
#  {'en': 'An adorable caleco cat sitting underneath a bicycle.',
#   'gu': 'સાયકલની નીચે બેસીને એક આકસ્મિક કેલેકો બિલાડી.'},
#  {'en': 'A sign in the grass stating the next highway. ',
#   'gu': 'આગામી ધોરીમાર્ગને દર્શાવતા ઘાસમાં નિશાની'},
#  {'en': 'a couple of young kids are reading books ',
#   'gu': 'કેટલાક યુવા બાળકો પુસ્તકો વાંચી રહ્યા છે'},
#  {'en': ' a street pole on the side of a road on herbert ave',
#   'gu': '\xa0હર્બર્ટ એવે પર રોડની બાજુમાં એક શેરીનો ધ્રુવ'},
#  {'en': 'a dog standing near a street sign on a dirt road',
#   'gu': 'ગંદકી માર્ગ પર શેરી સાઇન નજીક એક કૂતરો ઊભો છે'},
#  {'en': 'There is a long transit bus with an Asian driver.',
#   'gu': 'એશિયન ડ્રાઈવર સાથે લાંબી ટ્રાન્ઝિટ બસ છે.'},
#  {'en': 'a large tower with a clock and a small bird flying above it',
#   'gu': 'એક ઘડિયાળ અને તે ઉપરના એક નાના પક્ષી સાથે એક વિશાળ ટાવર'},
#  {'en': 'A woman sitting on top of a bench on a lush green field.',
#   'gu': 'એક હૂંફાળું લીલા ક્ષેત્ર પર એક બેન્ચ ઉપર બેઠા સ્ત્રી'},
#  {'en': 'A bathroom with a white toilet next to a sink.',
#   'gu': 'સિંકથી આગળ સફેદ શૌચાલય ધરાવતું બાથરૂમ.'},
#  {'en': 'Two train cars sitting on the tracks with power lines in the backround.',
#   'gu': 'બેક ટ્રેનમાં વીજળીની રેખાઓ સાથે ટ્રેક્સ પર બેઠેલા બે ટ્રેન કાર.'},
#  {'en': 'A green and white street sign that reads "traffic calmed neighborhood."',
#   'gu': 'લીલા અને સફેદ શેરી ચિહ્ન જે "ટ્રાફિક શાંત પડોશી" વાંચે છે.'},
#  {'en': 'Sunrise on an airport tarmac with a plane at the boarding ramp.',
#   'gu': 'બોર્ડિંગ રસ્તા પર પ્લેન સાથે એરપોર્ટ ટર્મક પર સૂર્યોદય'},
#  {'en': 'Inside a restroom with toilet along side of wall and shower on other side.',
#   'gu': 'બીજી બાજુ દિવાલ અને ફુવારોની બાજુમાં શૌચાલય સાથેના આરામખંડની અંદર.'},
#  {'en': 'A large herd of sheep walking along a rocky field.',
#   'gu': 'એક ખડકાળ ક્ષેત્ર સાથે ઘેટાંની મોટી ટોળું.'},
#  {'en': 'A tower that is next to a train.', 'gu': 'ટ્રેનની પાસેના એક ટાવર'},
#  {'en': 'A silver train passing under high beams and trees.',
#   'gu': 'ઊંચી બીમ અને ઝાડ નીચે પસાર થતી સિલ્વર ટ્રેન.'},
#  {'en': 'Two giraffes standing in the grass near a metal fence.',
#   'gu': 'મેટલ વાડ નજીકના ઘાસમાં બે જિરાફ ઊભા છે.'},
#  {'en': 'The view of a street stop sign with a mountain view.',
#   'gu': 'પર્વતીય દૃશ્ય સાથે ગલી સ્ટોપ સાઇનનો દેખાવ.'},
#  {'en': 'A train marked 800 is at a station.',
#   'gu': '800 ની એક ટ્રેન સ્ટેશન પર છે.'},
#  {'en': 'A one way sign pointing to the left; the sky is blue in the background. ',
#   'gu': 'ડાબી બાજુ તરફ સંકેત આપતી એક રીતે સહી; આકાશમાં વાદળી પૃષ્ઠભૂમિમાં છે.'},
#  {'en': 'A group of giraffes gathers in a field.',
#   'gu': 'જીરાફનું એક જૂથ ક્ષેત્રમાં એકત્ર કરે છે'},
#  {'en': 'A folk of birds flying over a military ship.',
#   'gu': 'એક લશ્કરી વહાણ પર ઉડતી પક્ષીઓ એક લોક.'},
#  {'en': 'A traffic light with a crosswalk sign and a one way sign on it.',
#   'gu': 'એક ક્રોસવૉક સાઇન સાથે ટ્રાફિક લાઇટ અને તેના પર એક માર્ગ સાઇન.'},
#  {'en': 'a person that is on a motorcycle in the dark',
#   'gu': 'એક વ્યક્તિ જે અંધારામાં મોટરસાઇકલ પર છે'},
#  {'en': 'A man doing a trick on a skateboard as another man watches.',
#   'gu': 'એક માણસ સ્કેટબોર્ડ પર યુક્તિ કરે છે કારણ કે અન્ય માણસ જુએ છે'},
#  {'en': 'A cat pears into the bowl of a toilet.',
#   'gu': 'એક શૌચાલયની વાટકીમાં બિલાડીનો નાશ કરે છે.'},
#  {'en': 'A row of numerous bike racks containing bikes for a race.',
#   'gu': 'રેસ માટે બાઇક ધરાવતી અસંખ્ય બાઇક રૅક્સની પંક્તિ.'},
#  ...]

# %%
# Access the training split of the dataset
train_dataset = dataset["train"]

# Select a subset of training samples
num_train_samples = 3000
train_subset = train_dataset.select(range(num_train_samples))
print(train_subset)
# Out:
# Dataset({
#     features: ['translation'],
#     num_rows: 3000
# })

# %%
# Load the T5 tokenizer
tokenizer = AutoTokenizer.from_pretrained("t5-small")
model = T5ForConditionalGeneration.from_pretrained("t5-small").to(device)

# %%
# Custom dataset class for translation
class TranslationDataset(torch.utils.data.Dataset):
    def __init__(self, data):
        self.data_items = data

    def __len__(self):
        return len(self.data_items)

    def __getitem__(self, index):
        example = self.data_items[index]
        source_text = example['translation']["en"]
        target_text = example['translation']["gu"]
        return source_text, target_text

    def collate_fn(self, batch):
        source_texts, target_texts = zip(*batch)
        source_inputs = tokenizer.batch_encode_plus(source_texts, padding="longest", truncation=True, max_length=512, return_tensors="pt")
        target_inputs = tokenizer.batch_encode_plus(target_texts, padding="longest", truncation=True, max_length=512, return_tensors="pt")
        input_ids = source_inputs["input_ids"].squeeze()
        attention_mask = source_inputs["attention_mask"].squeeze()
        labels = target_inputs["input_ids"].squeeze()
        decoder_attention_mask = target_inputs["attention_mask"].squeeze()
        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "labels": labels,
            "decoder_attention_mask": decoder_attention_mask,
        }

# %%
# Create the translation datasets and dataloaders
train_dataset = TranslationDataset(train_subset)
validation_dataset = TranslationDataset(dataset["validation"])
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=8, shuffle=True, collate_fn=train_dataset.collate_fn)
validation_dataloader = torch.utils.data.DataLoader(validation_dataset, batch_size=8, collate_fn=validation_dataset.collate_fn)

# %%
# Set the training parameters
num_epochs = 4
learning_rate = 1e-5
optimizer = AdamW(model.parameters(), lr=learning_rate)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Prepare the optimizer and scheduler
optimizer = AdamW(model.parameters(), lr=learning_rate)
total_steps = len(train_dataloader) * num_epochs
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=learning_rate, total_steps=total_steps)

# %%
print(len(train_dataloader))
# Out:
# 375

# %%
# Training loop
for epoch in range(num_epochs):
    model.train()
    total_loss = 0.0
    progress_bar = tqdm(train_dataloader, desc=f"Epoch {epoch+1}/{num_epochs}", unit="batch")
    for batch in progress_bar:
        optimizer.zero_grad()

        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)
        decoder_attention_mask = batch["decoder_attention_mask"].to(device)

        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=labels,
            decoder_attention_mask=decoder_attention_mask
        )

        loss = outputs.loss
        total_loss += loss.item()

        loss.backward()
        optimizer.step()

        progress_bar.set_postfix({"loss": loss.item()})

    average_loss = total_loss / len(train_dataloader)
    print(f"Epoch {epoch+1}/{num_epochs} - Average Loss: {average_loss}")

    # Validation loop
    model.eval()
    with torch.no_grad():
        total_val_loss = 0.0
        for val_batch in validation_dataloader:
            input_ids = val_batch["input_ids"].to(device)
            attention_mask = val_batch["attention_mask"].to(device)
            labels = val_batch["labels"].to(device)
            decoder_attention_mask = val_batch["decoder_attention_mask"].to(device)

            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                labels=labels,
                decoder_attention_mask=decoder_attention_mask
            )
            val_loss = outputs.loss
            total_val_loss += val_loss.item()

        average_val_loss = total_val_loss / len(validation_dataloader)
        print(f"Validation Loss: {average_val_loss}")
# Out:
# Epoch 1/4: 100%|██████████| 375/375 [14:14<00:00,  2.28s/batch, loss=2.84]
# Epoch 1/4 - Average Loss: 3.867903246243795
# Validation Loss: 3.030196715134841
# Epoch 2/4: 100%|██████████| 375/375 [13:52<00:00,  2.22s/batch, loss=3.32]
# Epoch 2/4 - Average Loss: 2.95347074731191
# Validation Loss: 1.7310846930283768
# Epoch 3/4: 100%|██████████| 375/375 [13:38<00:00,  2.18s/batch, loss=2.44]
# Epoch 3/4 - Average Loss: 2.1284131943384805
# Validation Loss: 0.9175038376679787
# Epoch 4/4: 100%|██████████| 375/375 [13:40<00:00,  2.19s/batch, loss=1.43]
# Epoch 4/4 - Average Loss: 1.6141133081118266
# Validation Loss: 0.6037931420367497

# %%
test_dataset = TranslationDataset(dataset["validation"])
test_dataloader = DataLoader(test_dataset, batch_size=16, collate_fn=test_dataset.collate_fn)

# %%
test_dataset

# %%
model.save_pretrained("fine_tuned_t5")

# %%
model.eval()
total_correct = 0
total_samples = 0

  
for example in test_dataset:
    source_text = example[0]
    target_text = example[1]
    
    # Tokenize the input text
    input_ids = tokenizer.encode(source_text, return_tensors="pt").to(device)
    
    # Generate the predicted output
    with torch.no_grad():
        output_ids = model.generate(input_ids)
    
    # Decode the predicted output
    predicted_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)
    
    # Compute accuracy
    if predicted_text == target_text:
        total_correct += 1
    total_samples += 1

accuracy = total_correct / total_samples
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1346: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
